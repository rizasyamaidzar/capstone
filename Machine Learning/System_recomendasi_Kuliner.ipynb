# %% [markdown]
# #Data Preparation

# %% [markdown]
# Install dan import package

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# Read Dataset

# %%
data_restaurant="https://docs.google.com/spreadsheets/d/e/2PACX-1vTyCBQxA1HyRnQWj-RXf-_5DXKn3L90Td0aO5r8DsTtE7pO3IQbPVvcuhfaCmJvTwiD_Hhvw34Xzbya/pub?gid=2129966204&single=true&output=csv"
data_makanminum="https://docs.google.com/spreadsheets/d/e/2PACX-1vTyCBQxA1HyRnQWj-RXf-_5DXKn3L90Td0aO5r8DsTtE7pO3IQbPVvcuhfaCmJvTwiD_Hhvw34Xzbya/pub?gid=477290477&single=true&output=csv"

# membaca kedua sheet ke dalam DataFrame
data_resto = pd.read_csv(data_restaurant)
data_makmin = pd.read_csv(data_makanminum)

print(data_resto.head())
print(data_makmin.head())
# Out:
#   resto_id                                      nama_restoran  \
# 0   RT01J1                Mie Bandung Chinese Food, Ngampilan
# 1   RT02J1  Soto Tauco Pekalongan Bu Iswi, Jalan Bimokurdo...
# 2   RT03J1                  Bakso Urat dan Mie Ayam "Pak Mir"
# 3   RT04J1  Soto Ayam Kampung Dan Soto Daging Sapi Pak Gendut
# 4   RT05J1                                          Toba Tabo
#
#   preferensi_makanan lokasi_restoran  Harga_Rata-Rata_Makanan_di_Toko (Rp)  \
# 0            Chinese         3.23 km                               39000.0
# 1          Indonesia         3.01 km                               19000.0
# 2          Indonesia         1.44 km                               18000.0
# 3          Indonesia         0.83 km                               22000.0
# 4            Chinese         2.13 km                               40000.0
#
#    rating_toko jenis_suasana toko_sering_diskon_(Ya/Tidak)  \
# 0          4.7        Santai                         Tidak
# 1          3.7        Santai                         Tidak
# 2          3.6        Santai                         Tidak
# 3          3.8        Santai                         Tidak
# 4          4.7        Santai                         Tidak
#
#                                      variasi_makanan  \
# 0  Bakmi, Nasi Goreng, Mie Ayam, Kwetiaw, Bakso P...
# 1  Bakso, Soto Tauco, Lontong, Es Teh, Es Jeruk, ...
# 2         Bakso, Sop Ayam, Jajanan, Es Jeruk, Es Teh
# 3  Soto Daging, Soto Ayam, Perkedel, Es Teh, Es J...
# 4  Sate Babi, Babi Kecap, Bakmi Babi, Kopi, Es Ko...
#
#   pelayanan_khusus_pasangan_(Ya/Tidak)  entertainment  keramaian_restoran  \
# 0                                Tidak            3.0                 3.0
# 1                                Tidak            2.0                 2.0
# 2                                Tidak            2.0                 2.0
# 3                                Tidak            1.0                 2.0
# 4                                Tidak            1.0                 3.0
#
#   disajikan/ambil_sendiri all_you_can_eat/ala_carte  \
# 0               Disajikan                 Ala Carte
# 1               Disajikan                 Ala Carte
# 2               Disajikan                 Ala Carte
# 3               Disajikan                 Ala Carte
# 4               Disajikan                 Ala Carte
#
#                                       Lokasi
# 0  https://maps.app.goo.gl/yEFoAbWDFhBcanBZ9
# 1  https://maps.app.goo.gl/j9gT3yrbncuXKaC48
# 2  https://maps.app.goo.gl/HLC7w9tvJ9wzLMNWA
# 3  https://maps.app.goo.gl/rfywQEnYXS61CDRj6
# 4  https://maps.app.goo.gl/oJM1xoJi1ttNvh9r7
#   mami_id makanan/minuman      kategori   \
# 0  MKJ001    Sate Klathak  Makanan Berat
# 1  MKJ002    Soto Kambing  Makanan Berat
# 2  MKJ003    Sate Kambing  Makanan Berat
# 3  MKJ004     Wedang Uwuh        Minuman
# 4  MKJ005          Bakpia        Jajanan
#
#                                 deskripsi_rasa
# 0                   Gurih, pedas, juicy, smoky
# 1  Gurih, pedas, rempah, segar, lezat, berkuah
# 2      Gurih, pedas, juicy, smoky, asin, manis
# 3                 Manis, hangat, rempah, segar
# 4                 Manis, lembut, gurih, kacang

# %% [markdown]
# Memilih kolom yang digunakan

# %%
data_makmin.columns = data_makmin.columns.str.strip()

columns_to_select = ['makanan/minuman', 'kategori', 'deskripsi_rasa']
makanan_data = data_makmin[columns_to_select]

print("\nDataset dengan kolom terpilih:")
print(makanan_data.head())
# Out:
# Dataset dengan kolom terpilih:
#   makanan/minuman       kategori                               deskripsi_rasa
# 0    Sate Klathak  Makanan Berat                   Gurih, pedas, juicy, smoky
# 1    Soto Kambing  Makanan Berat  Gurih, pedas, rempah, segar, lezat, berkuah
# 2    Sate Kambing  Makanan Berat      Gurih, pedas, juicy, smoky, asin, manis
# 3     Wedang Uwuh        Minuman                 Manis, hangat, rempah, segar
# 4          Bakpia        Jajanan                 Manis, lembut, gurih, kacang

# %%
#memilih kolom sheet data restoran
data_resto.columns = data_resto.columns.str.strip()

columns_select = ['nama_restoran', 'rating_toko', 'variasi_makanan']
restoran_data = data_resto[columns_select]

print("\nDataset dengan kolom terpilih:")
print(restoran_data.head())
# Out:
# Dataset dengan kolom terpilih:
#                                        nama_restoran  rating_toko  \
# 0                Mie Bandung Chinese Food, Ngampilan          4.7
# 1  Soto Tauco Pekalongan Bu Iswi, Jalan Bimokurdo...          3.7
# 2                  Bakso Urat dan Mie Ayam "Pak Mir"          3.6
# 3  Soto Ayam Kampung Dan Soto Daging Sapi Pak Gendut          3.8
# 4                                          Toba Tabo          4.7
#
#                                      variasi_makanan
# 0  Bakmi, Nasi Goreng, Mie Ayam, Kwetiaw, Bakso P...
# 1  Bakso, Soto Tauco, Lontong, Es Teh, Es Jeruk, ...
# 2         Bakso, Sop Ayam, Jajanan, Es Jeruk, Es Teh
# 3  Soto Daging, Soto Ayam, Perkedel, Es Teh, Es J...
# 4  Sate Babi, Babi Kecap, Bakmi Babi, Kopi, Es Ko...

# %% [markdown]
# #Rekomendasi makanan berdasarkan kategori dan deskripsi rasa

# %%
# Combine category and taste for content-based filtering
makanan_data['Features'] = makanan_data['kategori'] + ' ' + makanan_data['deskripsi_rasa']

# Mengganti nilai NaN dengan string kosong
makanan_data['Features'] = makanan_data['Features'].fillna('')

# Encode the text data using TF-IDF
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(makanan_data['Features'])

# %%
# TensorFlow model
class ContentBasedRecommender(tf.keras.Model):
    def __init__(self):
        super(ContentBasedRecommender, self).__init__()
        self.dense1 = tf.keras.layers.Dense(256, activation='relu')
        self.dense2 = tf.keras.layers.Dense(128, activation='relu')
        self.dense3 = tf.keras.layers.Dense(128, activation='relu')
        self.dense4 = tf.keras.layers.Dense(64, activation='relu')
        self.dropout = tf.keras.layers.Dropout(0.5)
        self.dense5 = tf.keras.layers.Dense(len(makanan_data), activation='softmax')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        x = self.dropout(x)
        return self.dense5(x)

# %%
# Input and output for training
X = tfidf_matrix.toarray()
y = tf.keras.utils.to_categorical(range(len(makanan_data)), len(makanan_data))

# Inisialisasi model
model = ContentBasedRecommender()

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(X, y, epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
# 11/11 - 2s - loss: 5.7779 - accuracy: 0.0000e+00 - 2s/epoch - 180ms/step
# Epoch 2/1000
# 11/11 - 0s - loss: 5.7678 - accuracy: 0.0062 - 114ms/epoch - 10ms/step
# Epoch 3/1000
# 11/11 - 0s - loss: 5.7576 - accuracy: 0.0155 - 70ms/epoch - 6ms/step
# Epoch 4/1000
# 11/11 - 0s - loss: 5.7502 - accuracy: 0.0124 - 75ms/epoch - 7ms/step
# Epoch 5/1000
# 11/11 - 0s - loss: 5.7273 - accuracy: 0.0093 - 62ms/epoch - 6ms/step
# Epoch 6/1000
# 11/11 - 0s - loss: 5.6955 - accuracy: 0.0093 - 61ms/epoch - 6ms/step
# Epoch 7/1000
# 11/11 - 0s - loss: 5.6345 - accuracy: 0.0093 - 64ms/epoch - 6ms/step
# Epoch 8/1000
# 11/11 - 0s - loss: 5.5407 - accuracy: 0.0124 - 56ms/epoch - 5ms/step
# Epoch 9/1000
# 11/11 - 0s - loss: 5.4283 - accuracy: 0.0248 - 75ms/epoch - 7ms/step
# Epoch 10/1000
# 11/11 - 0s - loss: 5.3070 - accuracy: 0.0155 - 54ms/epoch - 5ms/step
# Epoch 11/1000
# 11/11 - 0s - loss: 5.1778 - accuracy: 0.0248 - 51ms/epoch - 5ms/step
# Epoch 12/1000
# 11/11 - 0s - loss: 5.0220 - accuracy: 0.0342 - 56ms/epoch - 5ms/step
# Epoch 13/1000
# 11/11 - 0s - loss: 4.7875 - accuracy: 0.0435 - 53ms/epoch - 5ms/step
# Epoch 14/1000
# 11/11 - 0s - loss: 4.7036 - accuracy: 0.0217 - 55ms/epoch - 5ms/step
# Epoch 15/1000
# 11/11 - 0s - loss: 4.5297 - accuracy: 0.0683 - 83ms/epoch - 8ms/step
# Epoch 16/1000
# 11/11 - 0s - loss: 4.4574 - accuracy: 0.0497 - 77ms/epoch - 7ms/step
# Epoch 17/1000
# 11/11 - 0s - loss: 4.2828 - accuracy: 0.0745 - 60ms/epoch - 5ms/step
# Epoch 18/1000
# 11/11 - 0s - loss: 4.1259 - accuracy: 0.0807 - 54ms/epoch - 5ms/step
# Epoch 19/1000
# 11/11 - 0s - loss: 3.9447 - accuracy: 0.1056 - 57ms/epoch - 5ms/step
# Epoch 20/1000
# 11/11 - 0s - loss: 4.0373 - accuracy: 0.0807 - 94ms/epoch - 9ms/step
# Epoch 21/1000
# 11/11 - 0s - loss: 3.7935 - accuracy: 0.1273 - 116ms/epoch - 11ms/step
# Epoch 22/1000
# 11/11 - 0s - loss: 3.7575 - accuracy: 0.1180 - 124ms/epoch - 11ms/step
# Epoch 23/1000
# 11/11 - 0s - loss: 3.6442 - accuracy: 0.1429 - 101ms/epoch - 9ms/step
# Epoch 24/1000
# 11/11 - 0s - loss: 3.6431 - accuracy: 0.1242 - 82ms/epoch - 7ms/step
# Epoch 25/1000
# 11/11 - 0s - loss: 3.3688 - accuracy: 0.1832 - 85ms/epoch - 8ms/step
# Epoch 26/1000
# 11/11 - 0s - loss: 3.4097 - accuracy: 0.1366 - 104ms/epoch - 9ms/step
# Epoch 27/1000
# 11/11 - 0s - loss: 3.3371 - accuracy: 0.1770 - 81ms/epoch - 7ms/step
# Epoch 28/1000
# 11/11 - 0s - loss: 3.2444 - accuracy: 0.2174 - 77ms/epoch - 7ms/step
# Epoch 29/1000
# 11/11 - 0s - loss: 3.1183 - accuracy: 0.2236 - 122ms/epoch - 11ms/step
# Epoch 30/1000
# 11/11 - 0s - loss: 2.9595 - accuracy: 0.2484 - 115ms/epoch - 10ms/step
# Epoch 31/1000
# 11/11 - 0s - loss: 2.9593 - accuracy: 0.2205 - 117ms/epoch - 11ms/step
# Epoch 32/1000
# 11/11 - 0s - loss: 2.8933 - accuracy: 0.2547 - 87ms/epoch - 8ms/step
# Epoch 33/1000
# 11/11 - 0s - loss: 2.9153 - accuracy: 0.2453 - 88ms/epoch - 8ms/step
# Epoch 34/1000
# 11/11 - 0s - loss: 2.7734 - accuracy: 0.2826 - 80ms/epoch - 7ms/step
# Epoch 35/1000
# 11/11 - 0s - loss: 2.5928 - accuracy: 0.3199 - 89ms/epoch - 8ms/step
# Epoch 36/1000
# 11/11 - 0s - loss: 2.7069 - accuracy: 0.2795 - 132ms/epoch - 12ms/step
# Epoch 37/1000
# 11/11 - 0s - loss: 2.7288 - accuracy: 0.2640 - 104ms/epoch - 9ms/step
# Epoch 38/1000
# 11/11 - 0s - loss: 2.5771 - accuracy: 0.2733 - 102ms/epoch - 9ms/step
# Epoch 39/1000
# 11/11 - 0s - loss: 2.5614 - accuracy: 0.3509 - 64ms/epoch - 6ms/step
# Epoch 40/1000
# 11/11 - 0s - loss: 2.4652 - accuracy: 0.3385 - 79ms/epoch - 7ms/step
# Epoch 41/1000
# 11/11 - 0s - loss: 2.5795 - accuracy: 0.3012 - 67ms/epoch - 6ms/step
# Epoch 42/1000
# 11/11 - 0s - loss: 2.4691 - accuracy: 0.3106 - 71ms/epoch - 6ms/step
# Epoch 43/1000
# 11/11 - 0s - loss: 2.3379 - accuracy: 0.3230 - 114ms/epoch - 10ms/step
# Epoch 44/1000
# 11/11 - 0s - loss: 2.2824 - accuracy: 0.3354 - 86ms/epoch - 8ms/step
# Epoch 45/1000
# 11/11 - 0s - loss: 2.3627 - accuracy: 0.3416 - 82ms/epoch - 7ms/step
# Epoch 46/1000
# 11/11 - 0s - loss: 2.3521 - accuracy: 0.3292 - 58ms/epoch - 5ms/step
# Epoch 47/1000
# 11/11 - 0s - loss: 2.2379 - accuracy: 0.3696 - 72ms/epoch - 7ms/step
# Epoch 48/1000
# 11/11 - 0s - loss: 2.1613 - accuracy: 0.3727 - 83ms/epoch - 8ms/step
# Epoch 49/1000
# 11/11 - 0s - loss: 2.2418 - accuracy: 0.3696 - 80ms/epoch - 7ms/step
# Epoch 50/1000
# 11/11 - 0s - loss: 2.1137 - accuracy: 0.3758 - 72ms/epoch - 7ms/step
# Epoch 51/1000
# 11/11 - 0s - loss: 2.0592 - accuracy: 0.3665 - 72ms/epoch - 7ms/step
# Epoch 52/1000
# 11/11 - 0s - loss: 1.9831 - accuracy: 0.4099 - 69ms/epoch - 6ms/step
# Epoch 53/1000
# 11/11 - 0s - loss: 2.0161 - accuracy: 0.4068 - 78ms/epoch - 7ms/step
# Epoch 54/1000
# 11/11 - 0s - loss: 2.1821 - accuracy: 0.3416 - 93ms/epoch - 8ms/step
# Epoch 55/1000
# 11/11 - 0s - loss: 2.0737 - accuracy: 0.3665 - 95ms/epoch - 9ms/step
# Epoch 56/1000
# 11/11 - 0s - loss: 1.9538 - accuracy: 0.4130 - 87ms/epoch - 8ms/step
# Epoch 57/1000
# 11/11 - 0s - loss: 1.9374 - accuracy: 0.3944 - 79ms/epoch - 7ms/step
# Epoch 58/1000
# 11/11 - 0s - loss: 1.9796 - accuracy: 0.4193 - 102ms/epoch - 9ms/step
# Epoch 59/1000
# 11/11 - 0s - loss: 1.9839 - accuracy: 0.3913 - 95ms/epoch - 9ms/step
# Epoch 60/1000
# 11/11 - 0s - loss: 1.8835 - accuracy: 0.4286 - 91ms/epoch - 8ms/step
# Epoch 61/1000
# 11/11 - 0s - loss: 1.8671 - accuracy: 0.4317 - 133ms/epoch - 12ms/step
# Epoch 62/1000
# 11/11 - 0s - loss: 1.8181 - accuracy: 0.4255 - 81ms/epoch - 7ms/step
# Epoch 63/1000
# 11/11 - 0s - loss: 1.8148 - accuracy: 0.4255 - 60ms/epoch - 5ms/step
# Epoch 64/1000
# 11/11 - 0s - loss: 1.7003 - accuracy: 0.4752 - 63ms/epoch - 6ms/step
# Epoch 65/1000
# 11/11 - 0s - loss: 1.7942 - accuracy: 0.4317 - 70ms/epoch - 6ms/step
# Epoch 66/1000
# 11/11 - 0s - loss: 1.7688 - accuracy: 0.4441 - 59ms/epoch - 5ms/step
# Epoch 67/1000
# 11/11 - 0s - loss: 1.7447 - accuracy: 0.4410 - 86ms/epoch - 8ms/step
# Epoch 68/1000
# 11/11 - 0s - loss: 1.6322 - accuracy: 0.4814 - 87ms/epoch - 8ms/step
# Epoch 69/1000
# 11/11 - 0s - loss: 1.6802 - accuracy: 0.5311 - 80ms/epoch - 7ms/step
# Epoch 70/1000
# 11/11 - 0s - loss: 1.6898 - accuracy: 0.4814 - 64ms/epoch - 6ms/step
# Epoch 71/1000
# 11/11 - 0s - loss: 1.6732 - accuracy: 0.4658 - 79ms/epoch - 7ms/step
# Epoch 72/1000
# 11/11 - 0s - loss: 1.5751 - accuracy: 0.5217 - 58ms/epoch - 5ms/step
# Epoch 73/1000
# 11/11 - 0s - loss: 1.6885 - accuracy: 0.4379 - 54ms/epoch - 5ms/step
# Epoch 74/1000
# 11/11 - 0s - loss: 1.6659 - accuracy: 0.4783 - 69ms/epoch - 6ms/step
# Epoch 75/1000
# 11/11 - 0s - loss: 1.5769 - accuracy: 0.4783 - 53ms/epoch - 5ms/step
# Epoch 76/1000
# 11/11 - 0s - loss: 1.6041 - accuracy: 0.4938 - 68ms/epoch - 6ms/step
# Epoch 77/1000
# 11/11 - 0s - loss: 1.5938 - accuracy: 0.5155 - 53ms/epoch - 5ms/step
# Epoch 78/1000
# 11/11 - 0s - loss: 1.6277 - accuracy: 0.4720 - 56ms/epoch - 5ms/step
# Epoch 79/1000
# 11/11 - 0s - loss: 1.5981 - accuracy: 0.4596 - 55ms/epoch - 5ms/step
# Epoch 80/1000
# 11/11 - 0s - loss: 1.6091 - accuracy: 0.4689 - 61ms/epoch - 6ms/step
# Epoch 81/1000
# 11/11 - 0s - loss: 1.6478 - accuracy: 0.4534 - 52ms/epoch - 5ms/step
# Epoch 82/1000
# 11/11 - 0s - loss: 1.5062 - accuracy: 0.5248 - 63ms/epoch - 6ms/step
# Epoch 83/1000
# 11/11 - 0s - loss: 1.4698 - accuracy: 0.5248 - 78ms/epoch - 7ms/step
# Epoch 84/1000
# 11/11 - 0s - loss: 1.6804 - accuracy: 0.4472 - 65ms/epoch - 6ms/step
# Epoch 85/1000
# 11/11 - 0s - loss: 1.5252 - accuracy: 0.5093 - 54ms/epoch - 5ms/step
# Epoch 86/1000
# 11/11 - 0s - loss: 1.5261 - accuracy: 0.4845 - 62ms/epoch - 6ms/step
# Epoch 87/1000
# 11/11 - 0s - loss: 1.5311 - accuracy: 0.4814 - 79ms/epoch - 7ms/step
# Epoch 88/1000
# 11/11 - 0s - loss: 1.4241 - accuracy: 0.5155 - 65ms/epoch - 6ms/step
# Epoch 89/1000
# 11/11 - 0s - loss: 1.4785 - accuracy: 0.5373 - 69ms/epoch - 6ms/step
# Epoch 90/1000
# 11/11 - 0s - loss: 1.4442 - accuracy: 0.5155 - 53ms/epoch - 5ms/step
# Epoch 91/1000
# 11/11 - 0s - loss: 1.4548 - accuracy: 0.4876 - 63ms/epoch - 6ms/step
# Epoch 92/1000
# 11/11 - 0s - loss: 1.4174 - accuracy: 0.5342 - 57ms/epoch - 5ms/step
# Epoch 93/1000
# 11/11 - 0s - loss: 1.4298 - accuracy: 0.5342 - 73ms/epoch - 7ms/step
# Epoch 94/1000
# 11/11 - 0s - loss: 1.4355 - accuracy: 0.5062 - 65ms/epoch - 6ms/step
# Epoch 95/1000
# 11/11 - 0s - loss: 1.3692 - accuracy: 0.5745 - 56ms/epoch - 5ms/step
# Epoch 96/1000
# 11/11 - 0s - loss: 1.3951 - accuracy: 0.5217 - 53ms/epoch - 5ms/step
# Epoch 97/1000
# 11/11 - 0s - loss: 1.3712 - accuracy: 0.5559 - 68ms/epoch - 6ms/step
# Epoch 98/1000
# 11/11 - 0s - loss: 1.2636 - accuracy: 0.5466 - 64ms/epoch - 6ms/step
# Epoch 99/1000
# 11/11 - 0s - loss: 1.4599 - accuracy: 0.5311 - 58ms/epoch - 5ms/step
# Epoch 100/1000
# 11/11 - 0s - loss: 1.4390 - accuracy: 0.5186 - 62ms/epoch - 6ms/step
# Epoch 101/1000
# 11/11 - 0s - loss: 1.4395 - accuracy: 0.5031 - 71ms/epoch - 6ms/step
# Epoch 102/1000
# 11/11 - 0s - loss: 1.3648 - accuracy: 0.5963 - 86ms/epoch - 8ms/step
# Epoch 103/1000
# 11/11 - 0s - loss: 1.2099 - accuracy: 0.5745 - 63ms/epoch - 6ms/step
# Epoch 104/1000
# 11/11 - 0s - loss: 1.3896 - accuracy: 0.5248 - 80ms/epoch - 7ms/step
# Epoch 105/1000
# 11/11 - 0s - loss: 1.3303 - accuracy: 0.5590 - 86ms/epoch - 8ms/step
# Epoch 106/1000
# 11/11 - 0s - loss: 1.4796 - accuracy: 0.5466 - 59ms/epoch - 5ms/step
# Epoch 107/1000
# 11/11 - 0s - loss: 1.3672 - accuracy: 0.5435 - 55ms/epoch - 5ms/step
# Epoch 108/1000
# 11/11 - 0s - loss: 1.3871 - accuracy: 0.5248 - 58ms/epoch - 5ms/step
# Epoch 109/1000
# 11/11 - 0s - loss: 1.3801 - accuracy: 0.5031 - 55ms/epoch - 5ms/step
# Epoch 110/1000
# 11/11 - 0s - loss: 1.3745 - accuracy: 0.5683 - 61ms/epoch - 6ms/step
# Epoch 111/1000
# 11/11 - 0s - loss: 1.3488 - accuracy: 0.5311 - 90ms/epoch - 8ms/step
# Epoch 112/1000
# 11/11 - 0s - loss: 1.3448 - accuracy: 0.5373 - 56ms/epoch - 5ms/step
# Epoch 113/1000
# 11/11 - 0s - loss: 1.2672 - accuracy: 0.5776 - 83ms/epoch - 8ms/step
# Epoch 114/1000
# 11/11 - 0s - loss: 1.3466 - accuracy: 0.5311 - 69ms/epoch - 6ms/step
# Epoch 115/1000
# 11/11 - 0s - loss: 1.3531 - accuracy: 0.5155 - 75ms/epoch - 7ms/step
# Epoch 116/1000
# 11/11 - 0s - loss: 1.3117 - accuracy: 0.5466 - 60ms/epoch - 5ms/step
# Epoch 117/1000
# 11/11 - 0s - loss: 1.2780 - accuracy: 0.5621 - 52ms/epoch - 5ms/step
# Epoch 118/1000
# 11/11 - 0s - loss: 1.3348 - accuracy: 0.5217 - 60ms/epoch - 5ms/step
# Epoch 119/1000
# 11/11 - 0s - loss: 1.1749 - accuracy: 0.5714 - 79ms/epoch - 7ms/step
# Epoch 120/1000
# 11/11 - 0s - loss: 1.3124 - accuracy: 0.5155 - 100ms/epoch - 9ms/step
# Epoch 121/1000
# 11/11 - 0s - loss: 1.2435 - accuracy: 0.5559 - 73ms/epoch - 7ms/step
# Epoch 122/1000
# 11/11 - 0s - loss: 1.2433 - accuracy: 0.5870 - 68ms/epoch - 6ms/step
# Epoch 123/1000
# 11/11 - 0s - loss: 1.3278 - accuracy: 0.5497 - 61ms/epoch - 6ms/step
# Epoch 124/1000
# 11/11 - 0s - loss: 1.3078 - accuracy: 0.5155 - 76ms/epoch - 7ms/step
# Epoch 125/1000
# 11/11 - 0s - loss: 1.2676 - accuracy: 0.5870 - 63ms/epoch - 6ms/step
# Epoch 126/1000
# 11/11 - 0s - loss: 1.1904 - accuracy: 0.5807 - 70ms/epoch - 6ms/step
# Epoch 127/1000
# 11/11 - 0s - loss: 1.3090 - accuracy: 0.5342 - 62ms/epoch - 6ms/step
# Epoch 128/1000
# 11/11 - 0s - loss: 1.1828 - accuracy: 0.6025 - 60ms/epoch - 5ms/step
# Epoch 129/1000
# 11/11 - 0s - loss: 1.1943 - accuracy: 0.5776 - 96ms/epoch - 9ms/step
# Epoch 130/1000
# 11/11 - 0s - loss: 1.3022 - accuracy: 0.5528 - 148ms/epoch - 13ms/step
# Epoch 131/1000
# 11/11 - 0s - loss: 1.2415 - accuracy: 0.5559 - 58ms/epoch - 5ms/step
# Epoch 132/1000
# 11/11 - 0s - loss: 1.1773 - accuracy: 0.5652 - 70ms/epoch - 6ms/step
# Epoch 133/1000
# 11/11 - 0s - loss: 1.1772 - accuracy: 0.5994 - 72ms/epoch - 7ms/step
# Epoch 134/1000
# 11/11 - 0s - loss: 1.1145 - accuracy: 0.5901 - 63ms/epoch - 6ms/step
# Epoch 135/1000
# 11/11 - 0s - loss: 1.1665 - accuracy: 0.5807 - 64ms/epoch - 6ms/step
# Epoch 136/1000
# 11/11 - 0s - loss: 1.1633 - accuracy: 0.5683 - 101ms/epoch - 9ms/step
# Epoch 137/1000
# 11/11 - 0s - loss: 1.1513 - accuracy: 0.5901 - 106ms/epoch - 10ms/step
# Epoch 138/1000
# 11/11 - 0s - loss: 1.1626 - accuracy: 0.5963 - 112ms/epoch - 10ms/step
# Epoch 139/1000
# 11/11 - 0s - loss: 1.2209 - accuracy: 0.5807 - 111ms/epoch - 10ms/step
# Epoch 140/1000
# 11/11 - 0s - loss: 1.2006 - accuracy: 0.5714 - 111ms/epoch - 10ms/step
# Epoch 141/1000
# 11/11 - 0s - loss: 1.1180 - accuracy: 0.5994 - 78ms/epoch - 7ms/step
# Epoch 142/1000
# 11/11 - 0s - loss: 1.2165 - accuracy: 0.5559 - 77ms/epoch - 7ms/step
# Epoch 143/1000
# 11/11 - 0s - loss: 1.1804 - accuracy: 0.5590 - 67ms/epoch - 6ms/step
# Epoch 144/1000
# 11/11 - 0s - loss: 1.1666 - accuracy: 0.5683 - 93ms/epoch - 8ms/step
# Epoch 145/1000
# 11/11 - 0s - loss: 1.1182 - accuracy: 0.6087 - 84ms/epoch - 8ms/step
# Epoch 146/1000
# 11/11 - 0s - loss: 1.1708 - accuracy: 0.5745 - 94ms/epoch - 9ms/step
# Epoch 147/1000
# 11/11 - 0s - loss: 1.1420 - accuracy: 0.5807 - 72ms/epoch - 7ms/step
# Epoch 148/1000
# 11/11 - 0s - loss: 1.1811 - accuracy: 0.5870 - 64ms/epoch - 6ms/step
# Epoch 149/1000
# 11/11 - 0s - loss: 1.1187 - accuracy: 0.5932 - 78ms/epoch - 7ms/step
# Epoch 150/1000
# 11/11 - 0s - loss: 1.1303 - accuracy: 0.5870 - 102ms/epoch - 9ms/step
# Epoch 151/1000
# 11/11 - 0s - loss: 1.1796 - accuracy: 0.5963 - 86ms/epoch - 8ms/step
# Epoch 152/1000
# 11/11 - 0s - loss: 1.1139 - accuracy: 0.5994 - 73ms/epoch - 7ms/step
# Epoch 153/1000
# 11/11 - 0s - loss: 1.1222 - accuracy: 0.5807 - 55ms/epoch - 5ms/step
# Epoch 154/1000
# 11/11 - 0s - loss: 1.0408 - accuracy: 0.6118 - 82ms/epoch - 7ms/step
# Epoch 155/1000
# 11/11 - 0s - loss: 1.1028 - accuracy: 0.5963 - 68ms/epoch - 6ms/step
# Epoch 156/1000
# 11/11 - 0s - loss: 1.0682 - accuracy: 0.6149 - 63ms/epoch - 6ms/step
# Epoch 157/1000
# 11/11 - 0s - loss: 1.1404 - accuracy: 0.5901 - 82ms/epoch - 7ms/step
# Epoch 158/1000
# 11/11 - 0s - loss: 1.0953 - accuracy: 0.5963 - 65ms/epoch - 6ms/step
# Epoch 159/1000
# 11/11 - 0s - loss: 1.1241 - accuracy: 0.6056 - 81ms/epoch - 7ms/step
# Epoch 160/1000
# 11/11 - 0s - loss: 1.1356 - accuracy: 0.5683 - 85ms/epoch - 8ms/step
# Epoch 161/1000
# 11/11 - 0s - loss: 1.1609 - accuracy: 0.5994 - 61ms/epoch - 6ms/step
# Epoch 162/1000
# 11/11 - 0s - loss: 1.0728 - accuracy: 0.6180 - 91ms/epoch - 8ms/step
# Epoch 163/1000
# 11/11 - 0s - loss: 1.1258 - accuracy: 0.6025 - 143ms/epoch - 13ms/step
# Epoch 164/1000
# 11/11 - 0s - loss: 1.0532 - accuracy: 0.6366 - 116ms/epoch - 11ms/step
# Epoch 165/1000
# 11/11 - 0s - loss: 1.1370 - accuracy: 0.5901 - 94ms/epoch - 9ms/step
# Epoch 166/1000
# 11/11 - 0s - loss: 1.0041 - accuracy: 0.6366 - 71ms/epoch - 6ms/step
# Epoch 167/1000
# 11/11 - 0s - loss: 1.0381 - accuracy: 0.6242 - 84ms/epoch - 8ms/step
# Epoch 168/1000
# 11/11 - 0s - loss: 1.0928 - accuracy: 0.5807 - 66ms/epoch - 6ms/step
# Epoch 169/1000
# 11/11 - 0s - loss: 1.1346 - accuracy: 0.5901 - 96ms/epoch - 9ms/step
# Epoch 170/1000
# 11/11 - 0s - loss: 1.1160 - accuracy: 0.5994 - 61ms/epoch - 6ms/step
# Epoch 171/1000
# 11/11 - 0s - loss: 1.0766 - accuracy: 0.6180 - 76ms/epoch - 7ms/step
# Epoch 172/1000
# 11/11 - 0s - loss: 1.0463 - accuracy: 0.5870 - 96ms/epoch - 9ms/step
# Epoch 173/1000
# 11/11 - 0s - loss: 1.0769 - accuracy: 0.6087 - 114ms/epoch - 10ms/step
# Epoch 174/1000
# 11/11 - 0s - loss: 1.0337 - accuracy: 0.6056 - 88ms/epoch - 8ms/step
# Epoch 175/1000
# 11/11 - 0s - loss: 1.0565 - accuracy: 0.6087 - 65ms/epoch - 6ms/step
# Epoch 176/1000
# 11/11 - 0s - loss: 1.1410 - accuracy: 0.5901 - 67ms/epoch - 6ms/step
# Epoch 177/1000
# 11/11 - 0s - loss: 1.1009 - accuracy: 0.5683 - 74ms/epoch - 7ms/step
# Epoch 178/1000
# 11/11 - 0s - loss: 1.0371 - accuracy: 0.6087 - 69ms/epoch - 6ms/step
# Epoch 179/1000
# 11/11 - 0s - loss: 1.1601 - accuracy: 0.5839 - 61ms/epoch - 6ms/step
# Epoch 180/1000
# 11/11 - 0s - loss: 1.1307 - accuracy: 0.5776 - 68ms/epoch - 6ms/step
# Epoch 181/1000
# 11/11 - 0s - loss: 1.1465 - accuracy: 0.5466 - 75ms/epoch - 7ms/step
# Epoch 182/1000
# 11/11 - 0s - loss: 1.0712 - accuracy: 0.5870 - 83ms/epoch - 8ms/step
# Epoch 183/1000
# 11/11 - 0s - loss: 1.1518 - accuracy: 0.5683 - 74ms/epoch - 7ms/step
# Epoch 184/1000
# 11/11 - 0s - loss: 1.0264 - accuracy: 0.6242 - 86ms/epoch - 8ms/step
# Epoch 185/1000
# 11/11 - 0s - loss: 1.1280 - accuracy: 0.5932 - 89ms/epoch - 8ms/step
# Epoch 186/1000
# 11/11 - 0s - loss: 1.1399 - accuracy: 0.5901 - 90ms/epoch - 8ms/step
# Epoch 187/1000
# 11/11 - 0s - loss: 1.0952 - accuracy: 0.6056 - 103ms/epoch - 9ms/step
# Epoch 188/1000
# 11/11 - 0s - loss: 1.1249 - accuracy: 0.5745 - 78ms/epoch - 7ms/step
# Epoch 189/1000
# 11/11 - 0s - loss: 1.0351 - accuracy: 0.6180 - 104ms/epoch - 9ms/step
# Epoch 190/1000
# 11/11 - 0s - loss: 1.0322 - accuracy: 0.5870 - 59ms/epoch - 5ms/step
# Epoch 191/1000
# 11/11 - 0s - loss: 1.0890 - accuracy: 0.5994 - 95ms/epoch - 9ms/step
# Epoch 192/1000
# 11/11 - 0s - loss: 1.0624 - accuracy: 0.6211 - 86ms/epoch - 8ms/step
# Epoch 193/1000
# 11/11 - 0s - loss: 1.1062 - accuracy: 0.5435 - 95ms/epoch - 9ms/step
# Epoch 194/1000
# 11/11 - 0s - loss: 1.0091 - accuracy: 0.6118 - 92ms/epoch - 8ms/step
# Epoch 195/1000
# 11/11 - 0s - loss: 1.0308 - accuracy: 0.5839 - 110ms/epoch - 10ms/step
# Epoch 196/1000
# 11/11 - 0s - loss: 1.0306 - accuracy: 0.5963 - 115ms/epoch - 10ms/step
# Epoch 197/1000
# 11/11 - 0s - loss: 0.9874 - accuracy: 0.5839 - 97ms/epoch - 9ms/step
# Epoch 198/1000
# 11/11 - 0s - loss: 1.0258 - accuracy: 0.6087 - 110ms/epoch - 10ms/step
# Epoch 199/1000
# 11/11 - 0s - loss: 0.9331 - accuracy: 0.6335 - 120ms/epoch - 11ms/step
# Epoch 200/1000
# 11/11 - 0s - loss: 0.9912 - accuracy: 0.6304 - 103ms/epoch - 9ms/step
# Epoch 201/1000
# 11/11 - 0s - loss: 1.0010 - accuracy: 0.5994 - 160ms/epoch - 15ms/step
# Epoch 202/1000
# 11/11 - 0s - loss: 1.0270 - accuracy: 0.5932 - 104ms/epoch - 9ms/step
# Epoch 203/1000
# 11/11 - 0s - loss: 1.0069 - accuracy: 0.6242 - 109ms/epoch - 10ms/step
# Epoch 204/1000
# 11/11 - 0s - loss: 1.0025 - accuracy: 0.6118 - 100ms/epoch - 9ms/step
# Epoch 205/1000
# 11/11 - 0s - loss: 1.0871 - accuracy: 0.5714 - 83ms/epoch - 8ms/step
# Epoch 206/1000
# 11/11 - 0s - loss: 1.0226 - accuracy: 0.5994 - 87ms/epoch - 8ms/step
# Epoch 207/1000
# 11/11 - 0s - loss: 1.0194 - accuracy: 0.6242 - 117ms/epoch - 11ms/step
# Epoch 208/1000
# 11/11 - 0s - loss: 1.0251 - accuracy: 0.6242 - 78ms/epoch - 7ms/step
# Epoch 209/1000
# 11/11 - 0s - loss: 0.9704 - accuracy: 0.6273 - 110ms/epoch - 10ms/step
# Epoch 210/1000
# 11/11 - 0s - loss: 0.9998 - accuracy: 0.6429 - 170ms/epoch - 15ms/step
# Epoch 211/1000
# 11/11 - 0s - loss: 0.9986 - accuracy: 0.6087 - 95ms/epoch - 9ms/step
# Epoch 212/1000
# 11/11 - 0s - loss: 1.0158 - accuracy: 0.5994 - 123ms/epoch - 11ms/step
# Epoch 213/1000
# 11/11 - 0s - loss: 1.0513 - accuracy: 0.5963 - 71ms/epoch - 6ms/step
# Epoch 214/1000
# 11/11 - 0s - loss: 1.0868 - accuracy: 0.5621 - 99ms/epoch - 9ms/step
# Epoch 215/1000
# 11/11 - 0s - loss: 0.9600 - accuracy: 0.6149 - 75ms/epoch - 7ms/step
# Epoch 216/1000
# 11/11 - 0s - loss: 0.9544 - accuracy: 0.6304 - 57ms/epoch - 5ms/step
# Epoch 217/1000
# 11/11 - 0s - loss: 1.0630 - accuracy: 0.6025 - 84ms/epoch - 8ms/step
# Epoch 218/1000
# 11/11 - 0s - loss: 1.0192 - accuracy: 0.6149 - 85ms/epoch - 8ms/step
# Epoch 219/1000
# 11/11 - 0s - loss: 0.9592 - accuracy: 0.6429 - 79ms/epoch - 7ms/step
# Epoch 220/1000
# 11/11 - 0s - loss: 1.0391 - accuracy: 0.6056 - 79ms/epoch - 7ms/step
# Epoch 221/1000
# 11/11 - 0s - loss: 0.9663 - accuracy: 0.6366 - 76ms/epoch - 7ms/step
# Epoch 222/1000
# 11/11 - 0s - loss: 1.0044 - accuracy: 0.6180 - 78ms/epoch - 7ms/step
# Epoch 223/1000
# 11/11 - 0s - loss: 1.0355 - accuracy: 0.5963 - 80ms/epoch - 7ms/step
# Epoch 224/1000
# 11/11 - 0s - loss: 1.0086 - accuracy: 0.6118 - 77ms/epoch - 7ms/step
# Epoch 225/1000
# 11/11 - 0s - loss: 1.0142 - accuracy: 0.5901 - 91ms/epoch - 8ms/step
# Epoch 226/1000
# 11/11 - 0s - loss: 0.9952 - accuracy: 0.6087 - 88ms/epoch - 8ms/step
# Epoch 227/1000
# 11/11 - 0s - loss: 0.9495 - accuracy: 0.6211 - 116ms/epoch - 11ms/step
# Epoch 228/1000
# 11/11 - 0s - loss: 0.9505 - accuracy: 0.6273 - 117ms/epoch - 11ms/step
# Epoch 229/1000
# 11/11 - 0s - loss: 1.0456 - accuracy: 0.6056 - 76ms/epoch - 7ms/step
# Epoch 230/1000
# 11/11 - 0s - loss: 1.0029 - accuracy: 0.6118 - 87ms/epoch - 8ms/step
# Epoch 231/1000
# 11/11 - 0s - loss: 0.9286 - accuracy: 0.6398 - 93ms/epoch - 8ms/step
# Epoch 232/1000
# 11/11 - 0s - loss: 0.9375 - accuracy: 0.6398 - 82ms/epoch - 7ms/step
# Epoch 233/1000
# 11/11 - 0s - loss: 0.9766 - accuracy: 0.6273 - 81ms/epoch - 7ms/step
# Epoch 234/1000
# 11/11 - 0s - loss: 0.9783 - accuracy: 0.6087 - 57ms/epoch - 5ms/step
# Epoch 235/1000
# 11/11 - 0s - loss: 1.0349 - accuracy: 0.5994 - 73ms/epoch - 7ms/step
# Epoch 236/1000
# 11/11 - 0s - loss: 1.0612 - accuracy: 0.6056 - 142ms/epoch - 13ms/step
# Epoch 237/1000
# 11/11 - 0s - loss: 0.9963 - accuracy: 0.6242 - 128ms/epoch - 12ms/step
# Epoch 238/1000
# 11/11 - 0s - loss: 0.9864 - accuracy: 0.6366 - 102ms/epoch - 9ms/step
# Epoch 239/1000
# 11/11 - 0s - loss: 0.9727 - accuracy: 0.6273 - 124ms/epoch - 11ms/step
# Epoch 240/1000
# 11/11 - 0s - loss: 1.0610 - accuracy: 0.5901 - 133ms/epoch - 12ms/step
# Epoch 241/1000
# 11/11 - 0s - loss: 1.0354 - accuracy: 0.5932 - 161ms/epoch - 15ms/step
# Epoch 242/1000
# 11/11 - 0s - loss: 0.9676 - accuracy: 0.6304 - 90ms/epoch - 8ms/step
# Epoch 243/1000
# 11/11 - 0s - loss: 1.0497 - accuracy: 0.5901 - 58ms/epoch - 5ms/step
# Epoch 244/1000
# 11/11 - 0s - loss: 0.9570 - accuracy: 0.6335 - 64ms/epoch - 6ms/step
# Epoch 245/1000
# 11/11 - 0s - loss: 0.9582 - accuracy: 0.6335 - 125ms/epoch - 11ms/step
# Epoch 246/1000
# 11/11 - 0s - loss: 1.0697 - accuracy: 0.5652 - 86ms/epoch - 8ms/step
# Epoch 247/1000
# 11/11 - 0s - loss: 1.1309 - accuracy: 0.5776 - 54ms/epoch - 5ms/step
# Epoch 248/1000
# 11/11 - 0s - loss: 0.9924 - accuracy: 0.6242 - 57ms/epoch - 5ms/step
# Epoch 249/1000
# 11/11 - 0s - loss: 1.0038 - accuracy: 0.6056 - 83ms/epoch - 8ms/step
# Epoch 250/1000
# 11/11 - 0s - loss: 1.0177 - accuracy: 0.5839 - 60ms/epoch - 5ms/step
# Epoch 251/1000
# 11/11 - 0s - loss: 0.9918 - accuracy: 0.6180 - 52ms/epoch - 5ms/step
# Epoch 252/1000
# 11/11 - 0s - loss: 1.0577 - accuracy: 0.5839 - 56ms/epoch - 5ms/step
# Epoch 253/1000
# 11/11 - 0s - loss: 0.9965 - accuracy: 0.6149 - 57ms/epoch - 5ms/step
# Epoch 254/1000
# 11/11 - 0s - loss: 1.0048 - accuracy: 0.6149 - 56ms/epoch - 5ms/step
# Epoch 255/1000
# 11/11 - 0s - loss: 0.9719 - accuracy: 0.6366 - 60ms/epoch - 5ms/step
# Epoch 256/1000
# 11/11 - 0s - loss: 0.9615 - accuracy: 0.6211 - 84ms/epoch - 8ms/step
# Epoch 257/1000
# 11/11 - 0s - loss: 0.9817 - accuracy: 0.5994 - 59ms/epoch - 5ms/step
# Epoch 258/1000
# 11/11 - 0s - loss: 0.9696 - accuracy: 0.6273 - 84ms/epoch - 8ms/step
# Epoch 259/1000
# 11/11 - 0s - loss: 0.9430 - accuracy: 0.6366 - 65ms/epoch - 6ms/step
# Epoch 260/1000
# 11/11 - 0s - loss: 0.9928 - accuracy: 0.6025 - 72ms/epoch - 7ms/step
# Epoch 261/1000
# 11/11 - 0s - loss: 1.0357 - accuracy: 0.6180 - 88ms/epoch - 8ms/step
# Epoch 262/1000
# 11/11 - 0s - loss: 0.9936 - accuracy: 0.6056 - 72ms/epoch - 7ms/step
# Epoch 263/1000
# 11/11 - 0s - loss: 0.9671 - accuracy: 0.6335 - 37ms/epoch - 3ms/step
# Epoch 264/1000
# 11/11 - 0s - loss: 0.9681 - accuracy: 0.6304 - 36ms/epoch - 3ms/step
# Epoch 265/1000
# 11/11 - 0s - loss: 0.9748 - accuracy: 0.6180 - 38ms/epoch - 3ms/step
# Epoch 266/1000
# 11/11 - 0s - loss: 0.9921 - accuracy: 0.6025 - 36ms/epoch - 3ms/step
# Epoch 267/1000
# 11/11 - 0s - loss: 0.9531 - accuracy: 0.6304 - 42ms/epoch - 4ms/step
# Epoch 268/1000
# 11/11 - 0s - loss: 0.9846 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 269/1000
# 11/11 - 0s - loss: 0.9617 - accuracy: 0.6056 - 43ms/epoch - 4ms/step
# Epoch 270/1000
# 11/11 - 0s - loss: 0.9812 - accuracy: 0.6304 - 39ms/epoch - 4ms/step
# Epoch 271/1000
# 11/11 - 0s - loss: 0.9703 - accuracy: 0.5901 - 36ms/epoch - 3ms/step
# Epoch 272/1000
# 11/11 - 0s - loss: 1.0288 - accuracy: 0.5683 - 39ms/epoch - 4ms/step
# Epoch 273/1000
# 11/11 - 0s - loss: 0.9866 - accuracy: 0.6025 - 38ms/epoch - 3ms/step
# Epoch 274/1000
# 11/11 - 0s - loss: 0.9754 - accuracy: 0.6087 - 44ms/epoch - 4ms/step
# Epoch 275/1000
# 11/11 - 0s - loss: 0.9897 - accuracy: 0.5963 - 37ms/epoch - 3ms/step
# Epoch 276/1000
# 11/11 - 0s - loss: 1.0078 - accuracy: 0.5870 - 39ms/epoch - 4ms/step
# Epoch 277/1000
# 11/11 - 0s - loss: 0.9375 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 278/1000
# 11/11 - 0s - loss: 0.9588 - accuracy: 0.6491 - 57ms/epoch - 5ms/step
# Epoch 279/1000
# 11/11 - 0s - loss: 0.9590 - accuracy: 0.6335 - 36ms/epoch - 3ms/step
# Epoch 280/1000
# 11/11 - 0s - loss: 0.9717 - accuracy: 0.6118 - 38ms/epoch - 3ms/step
# Epoch 281/1000
# 11/11 - 0s - loss: 0.9842 - accuracy: 0.5994 - 40ms/epoch - 4ms/step
# Epoch 282/1000
# 11/11 - 0s - loss: 1.0173 - accuracy: 0.6025 - 38ms/epoch - 3ms/step
# Epoch 283/1000
# 11/11 - 0s - loss: 0.9353 - accuracy: 0.6242 - 39ms/epoch - 4ms/step
# Epoch 284/1000
# 11/11 - 0s - loss: 0.9451 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 285/1000
# 11/11 - 0s - loss: 0.9245 - accuracy: 0.6491 - 36ms/epoch - 3ms/step
# Epoch 286/1000
# 11/11 - 0s - loss: 0.9257 - accuracy: 0.6304 - 38ms/epoch - 3ms/step
# Epoch 287/1000
# 11/11 - 0s - loss: 0.9330 - accuracy: 0.6211 - 53ms/epoch - 5ms/step
# Epoch 288/1000
# 11/11 - 0s - loss: 0.9647 - accuracy: 0.6398 - 38ms/epoch - 3ms/step
# Epoch 289/1000
# 11/11 - 0s - loss: 0.9427 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 290/1000
# 11/11 - 0s - loss: 0.9010 - accuracy: 0.6584 - 39ms/epoch - 4ms/step
# Epoch 291/1000
# 11/11 - 0s - loss: 0.9113 - accuracy: 0.6553 - 36ms/epoch - 3ms/step
# Epoch 292/1000
# 11/11 - 0s - loss: 0.9456 - accuracy: 0.6180 - 36ms/epoch - 3ms/step
# Epoch 293/1000
# 11/11 - 0s - loss: 0.9021 - accuracy: 0.6366 - 37ms/epoch - 3ms/step
# Epoch 294/1000
# 11/11 - 0s - loss: 0.9531 - accuracy: 0.6087 - 34ms/epoch - 3ms/step
# Epoch 295/1000
# 11/11 - 0s - loss: 0.9393 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 296/1000
# 11/11 - 0s - loss: 0.9822 - accuracy: 0.5807 - 38ms/epoch - 3ms/step
# Epoch 297/1000
# 11/11 - 0s - loss: 1.1000 - accuracy: 0.5932 - 46ms/epoch - 4ms/step
# Epoch 298/1000
# 11/11 - 0s - loss: 0.9747 - accuracy: 0.5994 - 38ms/epoch - 3ms/step
# Epoch 299/1000
# 11/11 - 0s - loss: 1.0242 - accuracy: 0.5932 - 38ms/epoch - 3ms/step
# Epoch 300/1000
# 11/11 - 0s - loss: 1.0509 - accuracy: 0.5745 - 41ms/epoch - 4ms/step
# Epoch 301/1000
# 11/11 - 0s - loss: 0.9880 - accuracy: 0.6304 - 41ms/epoch - 4ms/step
# Epoch 302/1000
# 11/11 - 0s - loss: 0.9707 - accuracy: 0.6118 - 48ms/epoch - 4ms/step
# Epoch 303/1000
# 11/11 - 0s - loss: 1.0157 - accuracy: 0.6087 - 38ms/epoch - 3ms/step
# Epoch 304/1000
# 11/11 - 0s - loss: 0.9429 - accuracy: 0.6273 - 46ms/epoch - 4ms/step
# Epoch 305/1000
# 11/11 - 0s - loss: 0.9010 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 306/1000
# 11/11 - 0s - loss: 0.9623 - accuracy: 0.5901 - 43ms/epoch - 4ms/step
# Epoch 307/1000
# 11/11 - 0s - loss: 0.9879 - accuracy: 0.6118 - 38ms/epoch - 3ms/step
# Epoch 308/1000
# 11/11 - 0s - loss: 0.9839 - accuracy: 0.5839 - 39ms/epoch - 4ms/step
# Epoch 309/1000
# 11/11 - 0s - loss: 0.9638 - accuracy: 0.6056 - 37ms/epoch - 3ms/step
# Epoch 310/1000
# 11/11 - 0s - loss: 0.9344 - accuracy: 0.6118 - 36ms/epoch - 3ms/step
# Epoch 311/1000
# 11/11 - 0s - loss: 0.9759 - accuracy: 0.6087 - 37ms/epoch - 3ms/step
# Epoch 312/1000
# 11/11 - 0s - loss: 0.9462 - accuracy: 0.6118 - 37ms/epoch - 3ms/step
# Epoch 313/1000
# 11/11 - 0s - loss: 0.9989 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 314/1000
# 11/11 - 0s - loss: 0.9006 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 315/1000
# 11/11 - 0s - loss: 0.9511 - accuracy: 0.6398 - 41ms/epoch - 4ms/step
# Epoch 316/1000
# 11/11 - 0s - loss: 0.9638 - accuracy: 0.6335 - 37ms/epoch - 3ms/step
# Epoch 317/1000
# 11/11 - 0s - loss: 0.9059 - accuracy: 0.6398 - 38ms/epoch - 3ms/step
# Epoch 318/1000
# 11/11 - 0s - loss: 0.9951 - accuracy: 0.6304 - 39ms/epoch - 4ms/step
# Epoch 319/1000
# 11/11 - 0s - loss: 0.9642 - accuracy: 0.6211 - 41ms/epoch - 4ms/step
# Epoch 320/1000
# 11/11 - 0s - loss: 0.9913 - accuracy: 0.5901 - 38ms/epoch - 3ms/step
# Epoch 321/1000
# 11/11 - 0s - loss: 0.9720 - accuracy: 0.6056 - 38ms/epoch - 3ms/step
# Epoch 322/1000
# 11/11 - 0s - loss: 0.9476 - accuracy: 0.6304 - 39ms/epoch - 4ms/step
# Epoch 323/1000
# 11/11 - 0s - loss: 0.9259 - accuracy: 0.6304 - 38ms/epoch - 3ms/step
# Epoch 324/1000
# 11/11 - 0s - loss: 0.9404 - accuracy: 0.6118 - 40ms/epoch - 4ms/step
# Epoch 325/1000
# 11/11 - 0s - loss: 0.9909 - accuracy: 0.5870 - 40ms/epoch - 4ms/step
# Epoch 326/1000
# 11/11 - 0s - loss: 0.9158 - accuracy: 0.6522 - 52ms/epoch - 5ms/step
# Epoch 327/1000
# 11/11 - 0s - loss: 0.9292 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 328/1000
# 11/11 - 0s - loss: 1.0142 - accuracy: 0.6149 - 37ms/epoch - 3ms/step
# Epoch 329/1000
# 11/11 - 0s - loss: 0.9265 - accuracy: 0.6335 - 39ms/epoch - 4ms/step
# Epoch 330/1000
# 11/11 - 0s - loss: 0.9348 - accuracy: 0.6491 - 37ms/epoch - 3ms/step
# Epoch 331/1000
# 11/11 - 0s - loss: 0.9631 - accuracy: 0.6211 - 37ms/epoch - 3ms/step
# Epoch 332/1000
# 11/11 - 0s - loss: 1.0353 - accuracy: 0.5963 - 41ms/epoch - 4ms/step
# Epoch 333/1000
# 11/11 - 0s - loss: 0.9562 - accuracy: 0.6460 - 40ms/epoch - 4ms/step
# Epoch 334/1000
# 11/11 - 0s - loss: 0.9575 - accuracy: 0.6335 - 39ms/epoch - 4ms/step
# Epoch 335/1000
# 11/11 - 0s - loss: 0.9661 - accuracy: 0.6242 - 38ms/epoch - 3ms/step
# Epoch 336/1000
# 11/11 - 0s - loss: 0.9192 - accuracy: 0.6398 - 40ms/epoch - 4ms/step
# Epoch 337/1000
# 11/11 - 0s - loss: 0.9097 - accuracy: 0.6273 - 38ms/epoch - 3ms/step
# Epoch 338/1000
# 11/11 - 0s - loss: 0.9998 - accuracy: 0.5776 - 36ms/epoch - 3ms/step
# Epoch 339/1000
# 11/11 - 0s - loss: 0.8948 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 340/1000
# 11/11 - 0s - loss: 0.9921 - accuracy: 0.5963 - 40ms/epoch - 4ms/step
# Epoch 341/1000
# 11/11 - 0s - loss: 0.9413 - accuracy: 0.6335 - 39ms/epoch - 4ms/step
# Epoch 342/1000
# 11/11 - 0s - loss: 0.9302 - accuracy: 0.6118 - 37ms/epoch - 3ms/step
# Epoch 343/1000
# 11/11 - 0s - loss: 0.9426 - accuracy: 0.6211 - 37ms/epoch - 3ms/step
# Epoch 344/1000
# 11/11 - 0s - loss: 0.8639 - accuracy: 0.6615 - 37ms/epoch - 3ms/step
# Epoch 345/1000
# 11/11 - 0s - loss: 0.9813 - accuracy: 0.6149 - 36ms/epoch - 3ms/step
# Epoch 346/1000
# 11/11 - 0s - loss: 0.9641 - accuracy: 0.6056 - 35ms/epoch - 3ms/step
# Epoch 347/1000
# 11/11 - 0s - loss: 0.9725 - accuracy: 0.6304 - 37ms/epoch - 3ms/step
# Epoch 348/1000
# 11/11 - 0s - loss: 0.9119 - accuracy: 0.6087 - 44ms/epoch - 4ms/step
# Epoch 349/1000
# 11/11 - 0s - loss: 0.9374 - accuracy: 0.5932 - 40ms/epoch - 4ms/step
# Epoch 350/1000
# 11/11 - 0s - loss: 0.9331 - accuracy: 0.6491 - 50ms/epoch - 5ms/step
# Epoch 351/1000
# 11/11 - 0s - loss: 0.9731 - accuracy: 0.5932 - 38ms/epoch - 3ms/step
# Epoch 352/1000
# 11/11 - 0s - loss: 0.9215 - accuracy: 0.6273 - 41ms/epoch - 4ms/step
# Epoch 353/1000
# 11/11 - 0s - loss: 0.9814 - accuracy: 0.6180 - 39ms/epoch - 4ms/step
# Epoch 354/1000
# 11/11 - 0s - loss: 0.9305 - accuracy: 0.6242 - 39ms/epoch - 4ms/step
# Epoch 355/1000
# 11/11 - 0s - loss: 0.9654 - accuracy: 0.6242 - 39ms/epoch - 4ms/step
# Epoch 356/1000
# 11/11 - 0s - loss: 0.9679 - accuracy: 0.6273 - 38ms/epoch - 3ms/step
# Epoch 357/1000
# 11/11 - 0s - loss: 0.9696 - accuracy: 0.6087 - 46ms/epoch - 4ms/step
# Epoch 358/1000
# 11/11 - 0s - loss: 0.8992 - accuracy: 0.6429 - 41ms/epoch - 4ms/step
# Epoch 359/1000
# 11/11 - 0s - loss: 0.9178 - accuracy: 0.6304 - 40ms/epoch - 4ms/step
# Epoch 360/1000
# 11/11 - 0s - loss: 0.9026 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 361/1000
# 11/11 - 0s - loss: 0.9156 - accuracy: 0.6180 - 39ms/epoch - 4ms/step
# Epoch 362/1000
# 11/11 - 0s - loss: 0.9227 - accuracy: 0.6242 - 38ms/epoch - 3ms/step
# Epoch 363/1000
# 11/11 - 0s - loss: 0.9344 - accuracy: 0.6087 - 37ms/epoch - 3ms/step
# Epoch 364/1000
# 11/11 - 0s - loss: 0.9875 - accuracy: 0.6211 - 43ms/epoch - 4ms/step
# Epoch 365/1000
# 11/11 - 0s - loss: 0.9282 - accuracy: 0.6522 - 40ms/epoch - 4ms/step
# Epoch 366/1000
# 11/11 - 0s - loss: 0.8836 - accuracy: 0.6398 - 46ms/epoch - 4ms/step
# Epoch 367/1000
# 11/11 - 0s - loss: 0.9249 - accuracy: 0.6335 - 43ms/epoch - 4ms/step
# Epoch 368/1000
# 11/11 - 0s - loss: 0.9035 - accuracy: 0.6118 - 39ms/epoch - 4ms/step
# Epoch 369/1000
# 11/11 - 0s - loss: 0.9256 - accuracy: 0.6273 - 39ms/epoch - 4ms/step
# Epoch 370/1000
# 11/11 - 0s - loss: 0.8722 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 371/1000
# 11/11 - 0s - loss: 1.0402 - accuracy: 0.6180 - 39ms/epoch - 4ms/step
# Epoch 372/1000
# 11/11 - 0s - loss: 0.9986 - accuracy: 0.6118 - 39ms/epoch - 4ms/step
# Epoch 373/1000
# 11/11 - 0s - loss: 0.9707 - accuracy: 0.6056 - 50ms/epoch - 5ms/step
# Epoch 374/1000
# 11/11 - 0s - loss: 1.0595 - accuracy: 0.6118 - 42ms/epoch - 4ms/step
# Epoch 375/1000
# 11/11 - 0s - loss: 1.0962 - accuracy: 0.5901 - 42ms/epoch - 4ms/step
# Epoch 376/1000
# 11/11 - 0s - loss: 1.0764 - accuracy: 0.5497 - 37ms/epoch - 3ms/step
# Epoch 377/1000
# 11/11 - 0s - loss: 1.0023 - accuracy: 0.6087 - 38ms/epoch - 3ms/step
# Epoch 378/1000
# 11/11 - 0s - loss: 0.9553 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 379/1000
# 11/11 - 0s - loss: 0.9746 - accuracy: 0.6180 - 41ms/epoch - 4ms/step
# Epoch 380/1000
# 11/11 - 0s - loss: 0.9080 - accuracy: 0.6304 - 37ms/epoch - 3ms/step
# Epoch 381/1000
# 11/11 - 0s - loss: 0.9012 - accuracy: 0.6149 - 38ms/epoch - 3ms/step
# Epoch 382/1000
# 11/11 - 0s - loss: 0.9857 - accuracy: 0.5963 - 46ms/epoch - 4ms/step
# Epoch 383/1000
# 11/11 - 0s - loss: 0.9364 - accuracy: 0.6118 - 37ms/epoch - 3ms/step
# Epoch 384/1000
# 11/11 - 0s - loss: 0.9420 - accuracy: 0.6242 - 39ms/epoch - 4ms/step
# Epoch 385/1000
# 11/11 - 0s - loss: 0.9858 - accuracy: 0.6056 - 39ms/epoch - 4ms/step
# Epoch 386/1000
# 11/11 - 0s - loss: 0.9103 - accuracy: 0.6553 - 38ms/epoch - 3ms/step
# Epoch 387/1000
# 11/11 - 0s - loss: 0.9647 - accuracy: 0.6211 - 39ms/epoch - 4ms/step
# Epoch 388/1000
# 11/11 - 0s - loss: 0.9078 - accuracy: 0.6429 - 41ms/epoch - 4ms/step
# Epoch 389/1000
# 11/11 - 0s - loss: 0.8947 - accuracy: 0.6366 - 42ms/epoch - 4ms/step
# Epoch 390/1000
# 11/11 - 0s - loss: 0.9319 - accuracy: 0.6118 - 46ms/epoch - 4ms/step
# Epoch 391/1000
# 11/11 - 0s - loss: 0.9467 - accuracy: 0.6242 - 41ms/epoch - 4ms/step
# Epoch 392/1000
# 11/11 - 0s - loss: 0.9462 - accuracy: 0.6242 - 41ms/epoch - 4ms/step
# Epoch 393/1000
# 11/11 - 0s - loss: 0.8978 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 394/1000
# 11/11 - 0s - loss: 0.9133 - accuracy: 0.6242 - 41ms/epoch - 4ms/step
# Epoch 395/1000
# 11/11 - 0s - loss: 0.8834 - accuracy: 0.6211 - 41ms/epoch - 4ms/step
# Epoch 396/1000
# 11/11 - 0s - loss: 0.8390 - accuracy: 0.6801 - 40ms/epoch - 4ms/step
# Epoch 397/1000
# 11/11 - 0s - loss: 0.9293 - accuracy: 0.6366 - 53ms/epoch - 5ms/step
# Epoch 398/1000
# 11/11 - 0s - loss: 0.9235 - accuracy: 0.6366 - 42ms/epoch - 4ms/step
# Epoch 399/1000
# 11/11 - 0s - loss: 0.8944 - accuracy: 0.6087 - 39ms/epoch - 4ms/step
# Epoch 400/1000
# 11/11 - 0s - loss: 0.9146 - accuracy: 0.6460 - 39ms/epoch - 4ms/step
# Epoch 401/1000
# 11/11 - 0s - loss: 0.8870 - accuracy: 0.6398 - 39ms/epoch - 4ms/step
# Epoch 402/1000
# 11/11 - 0s - loss: 0.8751 - accuracy: 0.6739 - 39ms/epoch - 4ms/step
# Epoch 403/1000
# 11/11 - 0s - loss: 0.9068 - accuracy: 0.6491 - 41ms/epoch - 4ms/step
# Epoch 404/1000
# 11/11 - 0s - loss: 0.8481 - accuracy: 0.6522 - 42ms/epoch - 4ms/step
# Epoch 405/1000
# 11/11 - 0s - loss: 0.9561 - accuracy: 0.6025 - 41ms/epoch - 4ms/step
# Epoch 406/1000
# 11/11 - 0s - loss: 0.9395 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 407/1000
# 11/11 - 0s - loss: 0.9308 - accuracy: 0.6273 - 44ms/epoch - 4ms/step
# Epoch 408/1000
# 11/11 - 0s - loss: 0.9747 - accuracy: 0.5932 - 39ms/epoch - 4ms/step
# Epoch 409/1000
# 11/11 - 0s - loss: 0.9289 - accuracy: 0.6273 - 41ms/epoch - 4ms/step
# Epoch 410/1000
# 11/11 - 0s - loss: 0.8717 - accuracy: 0.6211 - 40ms/epoch - 4ms/step
# Epoch 411/1000
# 11/11 - 0s - loss: 0.9301 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 412/1000
# 11/11 - 0s - loss: 0.9606 - accuracy: 0.6025 - 38ms/epoch - 3ms/step
# Epoch 413/1000
# 11/11 - 0s - loss: 0.9291 - accuracy: 0.6366 - 41ms/epoch - 4ms/step
# Epoch 414/1000
# 11/11 - 0s - loss: 0.9000 - accuracy: 0.6304 - 40ms/epoch - 4ms/step
# Epoch 415/1000
# 11/11 - 0s - loss: 0.9037 - accuracy: 0.6304 - 38ms/epoch - 3ms/step
# Epoch 416/1000
# 11/11 - 0s - loss: 0.8575 - accuracy: 0.6739 - 38ms/epoch - 3ms/step
# Epoch 417/1000
# 11/11 - 0s - loss: 0.8706 - accuracy: 0.6304 - 37ms/epoch - 3ms/step
# Epoch 418/1000
# 11/11 - 0s - loss: 0.8940 - accuracy: 0.6366 - 37ms/epoch - 3ms/step
# Epoch 419/1000
# 11/11 - 0s - loss: 0.8888 - accuracy: 0.6429 - 34ms/epoch - 3ms/step
# Epoch 420/1000
# 11/11 - 0s - loss: 0.8506 - accuracy: 0.6553 - 46ms/epoch - 4ms/step
# Epoch 421/1000
# 11/11 - 0s - loss: 0.8796 - accuracy: 0.6335 - 42ms/epoch - 4ms/step
# Epoch 422/1000
# 11/11 - 0s - loss: 0.8510 - accuracy: 0.6553 - 41ms/epoch - 4ms/step
# Epoch 423/1000
# 11/11 - 0s - loss: 0.8658 - accuracy: 0.6677 - 41ms/epoch - 4ms/step
# Epoch 424/1000
# 11/11 - 0s - loss: 0.8934 - accuracy: 0.6398 - 36ms/epoch - 3ms/step
# Epoch 425/1000
# 11/11 - 0s - loss: 0.9286 - accuracy: 0.6025 - 41ms/epoch - 4ms/step
# Epoch 426/1000
# 11/11 - 0s - loss: 0.8806 - accuracy: 0.6273 - 52ms/epoch - 5ms/step
# Epoch 427/1000
# 11/11 - 0s - loss: 0.9438 - accuracy: 0.6056 - 56ms/epoch - 5ms/step
# Epoch 428/1000
# 11/11 - 0s - loss: 0.9182 - accuracy: 0.6242 - 48ms/epoch - 4ms/step
# Epoch 429/1000
# 11/11 - 0s - loss: 0.9799 - accuracy: 0.6398 - 55ms/epoch - 5ms/step
# Epoch 430/1000
# 11/11 - 0s - loss: 0.9571 - accuracy: 0.6273 - 54ms/epoch - 5ms/step
# Epoch 431/1000
# 11/11 - 0s - loss: 0.9183 - accuracy: 0.6304 - 51ms/epoch - 5ms/step
# Epoch 432/1000
# 11/11 - 0s - loss: 0.9298 - accuracy: 0.6211 - 60ms/epoch - 5ms/step
# Epoch 433/1000
# 11/11 - 0s - loss: 0.8880 - accuracy: 0.6460 - 65ms/epoch - 6ms/step
# Epoch 434/1000
# 11/11 - 0s - loss: 0.8915 - accuracy: 0.6398 - 52ms/epoch - 5ms/step
# Epoch 435/1000
# 11/11 - 0s - loss: 0.8936 - accuracy: 0.6398 - 56ms/epoch - 5ms/step
# Epoch 436/1000
# 11/11 - 0s - loss: 0.9043 - accuracy: 0.6211 - 50ms/epoch - 5ms/step
# Epoch 437/1000
# 11/11 - 0s - loss: 0.9499 - accuracy: 0.6025 - 49ms/epoch - 4ms/step
# Epoch 438/1000
# 11/11 - 0s - loss: 0.9176 - accuracy: 0.6366 - 52ms/epoch - 5ms/step
# Epoch 439/1000
# 11/11 - 0s - loss: 0.9638 - accuracy: 0.6056 - 57ms/epoch - 5ms/step
# Epoch 440/1000
# 11/11 - 0s - loss: 0.9243 - accuracy: 0.6366 - 50ms/epoch - 5ms/step
# Epoch 441/1000
# 11/11 - 0s - loss: 0.9059 - accuracy: 0.6273 - 56ms/epoch - 5ms/step
# Epoch 442/1000
# 11/11 - 0s - loss: 0.9027 - accuracy: 0.6366 - 51ms/epoch - 5ms/step
# Epoch 443/1000
# 11/11 - 0s - loss: 0.9174 - accuracy: 0.6398 - 52ms/epoch - 5ms/step
# Epoch 444/1000
# 11/11 - 0s - loss: 0.9338 - accuracy: 0.6273 - 50ms/epoch - 5ms/step
# Epoch 445/1000
# 11/11 - 0s - loss: 0.9206 - accuracy: 0.6242 - 50ms/epoch - 5ms/step
# Epoch 446/1000
# 11/11 - 0s - loss: 1.1268 - accuracy: 0.5745 - 63ms/epoch - 6ms/step
# Epoch 447/1000
# 11/11 - 0s - loss: 0.9672 - accuracy: 0.6273 - 48ms/epoch - 4ms/step
# Epoch 448/1000
# 11/11 - 0s - loss: 0.9273 - accuracy: 0.6242 - 53ms/epoch - 5ms/step
# Epoch 449/1000
# 11/11 - 0s - loss: 0.9515 - accuracy: 0.6025 - 53ms/epoch - 5ms/step
# Epoch 450/1000
# 11/11 - 0s - loss: 0.9739 - accuracy: 0.6149 - 51ms/epoch - 5ms/step
# Epoch 451/1000
# 11/11 - 0s - loss: 0.9109 - accuracy: 0.6242 - 56ms/epoch - 5ms/step
# Epoch 452/1000
# 11/11 - 0s - loss: 0.9431 - accuracy: 0.5994 - 50ms/epoch - 5ms/step
# Epoch 453/1000
# 11/11 - 0s - loss: 0.8937 - accuracy: 0.6211 - 48ms/epoch - 4ms/step
# Epoch 454/1000
# 11/11 - 0s - loss: 0.9179 - accuracy: 0.6366 - 52ms/epoch - 5ms/step
# Epoch 455/1000
# 11/11 - 0s - loss: 0.8798 - accuracy: 0.6522 - 49ms/epoch - 4ms/step
# Epoch 456/1000
# 11/11 - 0s - loss: 0.9053 - accuracy: 0.6398 - 51ms/epoch - 5ms/step
# Epoch 457/1000
# 11/11 - 0s - loss: 0.9440 - accuracy: 0.6304 - 54ms/epoch - 5ms/step
# Epoch 458/1000
# 11/11 - 0s - loss: 0.9658 - accuracy: 0.6429 - 48ms/epoch - 4ms/step
# Epoch 459/1000
# 11/11 - 0s - loss: 0.9421 - accuracy: 0.6273 - 60ms/epoch - 5ms/step
# Epoch 460/1000
# 11/11 - 0s - loss: 0.9210 - accuracy: 0.6429 - 53ms/epoch - 5ms/step
# Epoch 461/1000
# 11/11 - 0s - loss: 0.9149 - accuracy: 0.6149 - 49ms/epoch - 4ms/step
# Epoch 462/1000
# 11/11 - 0s - loss: 0.8973 - accuracy: 0.6180 - 57ms/epoch - 5ms/step
# Epoch 463/1000
# 11/11 - 0s - loss: 0.9234 - accuracy: 0.6087 - 49ms/epoch - 4ms/step
# Epoch 464/1000
# 11/11 - 0s - loss: 0.9023 - accuracy: 0.6335 - 61ms/epoch - 6ms/step
# Epoch 465/1000
# 11/11 - 0s - loss: 0.9184 - accuracy: 0.6335 - 48ms/epoch - 4ms/step
# Epoch 466/1000
# 11/11 - 0s - loss: 0.9096 - accuracy: 0.6429 - 55ms/epoch - 5ms/step
# Epoch 467/1000
# 11/11 - 0s - loss: 0.9200 - accuracy: 0.6087 - 50ms/epoch - 5ms/step
# Epoch 468/1000
# 11/11 - 0s - loss: 0.9198 - accuracy: 0.6056 - 50ms/epoch - 5ms/step
# Epoch 469/1000
# 11/11 - 0s - loss: 0.9236 - accuracy: 0.6366 - 47ms/epoch - 4ms/step
# Epoch 470/1000
# 11/11 - 0s - loss: 0.9190 - accuracy: 0.6273 - 56ms/epoch - 5ms/step
# Epoch 471/1000
# 11/11 - 0s - loss: 0.9277 - accuracy: 0.6242 - 52ms/epoch - 5ms/step
# Epoch 472/1000
# 11/11 - 0s - loss: 0.9312 - accuracy: 0.5994 - 56ms/epoch - 5ms/step
# Epoch 473/1000
# 11/11 - 0s - loss: 0.9154 - accuracy: 0.6211 - 58ms/epoch - 5ms/step
# Epoch 474/1000
# 11/11 - 0s - loss: 0.8759 - accuracy: 0.6242 - 55ms/epoch - 5ms/step
# Epoch 475/1000
# 11/11 - 0s - loss: 0.8817 - accuracy: 0.6149 - 54ms/epoch - 5ms/step
# Epoch 476/1000
# 11/11 - 0s - loss: 0.8469 - accuracy: 0.6398 - 56ms/epoch - 5ms/step
# Epoch 477/1000
# 11/11 - 0s - loss: 0.8809 - accuracy: 0.6273 - 58ms/epoch - 5ms/step
# Epoch 478/1000
# 11/11 - 0s - loss: 0.8754 - accuracy: 0.6242 - 57ms/epoch - 5ms/step
# Epoch 479/1000
# 11/11 - 0s - loss: 0.8590 - accuracy: 0.6522 - 59ms/epoch - 5ms/step
# Epoch 480/1000
# 11/11 - 0s - loss: 0.8855 - accuracy: 0.6180 - 55ms/epoch - 5ms/step
# Epoch 481/1000
# 11/11 - 0s - loss: 0.8958 - accuracy: 0.6646 - 56ms/epoch - 5ms/step
# Epoch 482/1000
# 11/11 - 0s - loss: 0.8739 - accuracy: 0.6180 - 52ms/epoch - 5ms/step
# Epoch 483/1000
# 11/11 - 0s - loss: 0.8991 - accuracy: 0.6149 - 54ms/epoch - 5ms/step
# Epoch 484/1000
# 11/11 - 0s - loss: 0.8505 - accuracy: 0.6491 - 53ms/epoch - 5ms/step
# Epoch 485/1000
# 11/11 - 0s - loss: 0.8611 - accuracy: 0.6398 - 53ms/epoch - 5ms/step
# Epoch 486/1000
# 11/11 - 0s - loss: 0.9142 - accuracy: 0.6180 - 54ms/epoch - 5ms/step
# Epoch 487/1000
# 11/11 - 0s - loss: 0.8737 - accuracy: 0.6584 - 54ms/epoch - 5ms/step
# Epoch 488/1000
# 11/11 - 0s - loss: 0.9172 - accuracy: 0.6056 - 54ms/epoch - 5ms/step
# Epoch 489/1000
# 11/11 - 0s - loss: 0.8626 - accuracy: 0.6273 - 54ms/epoch - 5ms/step
# Epoch 490/1000
# 11/11 - 0s - loss: 0.8469 - accuracy: 0.6739 - 52ms/epoch - 5ms/step
# Epoch 491/1000
# 11/11 - 0s - loss: 0.8341 - accuracy: 0.6584 - 52ms/epoch - 5ms/step
# Epoch 492/1000
# 11/11 - 0s - loss: 0.9031 - accuracy: 0.6398 - 54ms/epoch - 5ms/step
# Epoch 493/1000
# 11/11 - 0s - loss: 0.8379 - accuracy: 0.6584 - 56ms/epoch - 5ms/step
# Epoch 494/1000
# 11/11 - 0s - loss: 0.8912 - accuracy: 0.6056 - 59ms/epoch - 5ms/step
# Epoch 495/1000
# 11/11 - 0s - loss: 0.8608 - accuracy: 0.6553 - 65ms/epoch - 6ms/step
# Epoch 496/1000
# 11/11 - 0s - loss: 0.8665 - accuracy: 0.6398 - 59ms/epoch - 5ms/step
# Epoch 497/1000
# 11/11 - 0s - loss: 0.9180 - accuracy: 0.6211 - 56ms/epoch - 5ms/step
# Epoch 498/1000
# 11/11 - 0s - loss: 0.8805 - accuracy: 0.6273 - 55ms/epoch - 5ms/step
# Epoch 499/1000
# 11/11 - 0s - loss: 0.8562 - accuracy: 0.6584 - 64ms/epoch - 6ms/step
# Epoch 500/1000
# 11/11 - 0s - loss: 0.9269 - accuracy: 0.5901 - 55ms/epoch - 5ms/step
# Epoch 501/1000
# 11/11 - 0s - loss: 0.8945 - accuracy: 0.6460 - 64ms/epoch - 6ms/step
# Epoch 502/1000
# 11/11 - 0s - loss: 0.8701 - accuracy: 0.6429 - 60ms/epoch - 5ms/step
# Epoch 503/1000
# 11/11 - 0s - loss: 0.8995 - accuracy: 0.6366 - 71ms/epoch - 6ms/step
# Epoch 504/1000
# 11/11 - 0s - loss: 0.8718 - accuracy: 0.6366 - 59ms/epoch - 5ms/step
# Epoch 505/1000
# 11/11 - 0s - loss: 0.8723 - accuracy: 0.6398 - 45ms/epoch - 4ms/step
# Epoch 506/1000
# 11/11 - 0s - loss: 0.8782 - accuracy: 0.6180 - 39ms/epoch - 4ms/step
# Epoch 507/1000
# 11/11 - 0s - loss: 0.9090 - accuracy: 0.6211 - 39ms/epoch - 4ms/step
# Epoch 508/1000
# 11/11 - 0s - loss: 0.9103 - accuracy: 0.6491 - 41ms/epoch - 4ms/step
# Epoch 509/1000
# 11/11 - 0s - loss: 0.8573 - accuracy: 0.6366 - 37ms/epoch - 3ms/step
# Epoch 510/1000
# 11/11 - 0s - loss: 0.8498 - accuracy: 0.6553 - 37ms/epoch - 3ms/step
# Epoch 511/1000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6708 - 36ms/epoch - 3ms/step
# Epoch 512/1000
# 11/11 - 0s - loss: 0.8896 - accuracy: 0.6429 - 40ms/epoch - 4ms/step
# Epoch 513/1000
# 11/11 - 0s - loss: 0.8977 - accuracy: 0.6429 - 42ms/epoch - 4ms/step
# Epoch 514/1000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6180 - 42ms/epoch - 4ms/step
# Epoch 515/1000
# 11/11 - 0s - loss: 0.8420 - accuracy: 0.6553 - 53ms/epoch - 5ms/step
# Epoch 516/1000
# 11/11 - 0s - loss: 0.8809 - accuracy: 0.6398 - 39ms/epoch - 4ms/step
# Epoch 517/1000
# 11/11 - 0s - loss: 0.8831 - accuracy: 0.6149 - 37ms/epoch - 3ms/step
# Epoch 518/1000
# 11/11 - 0s - loss: 0.8982 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 519/1000
# 11/11 - 0s - loss: 0.9185 - accuracy: 0.6118 - 38ms/epoch - 3ms/step
# Epoch 520/1000
# 11/11 - 0s - loss: 0.8509 - accuracy: 0.6553 - 36ms/epoch - 3ms/step
# Epoch 521/1000
# 11/11 - 0s - loss: 0.8652 - accuracy: 0.6304 - 44ms/epoch - 4ms/step
# Epoch 522/1000
# 11/11 - 0s - loss: 0.8716 - accuracy: 0.6304 - 40ms/epoch - 4ms/step
# Epoch 523/1000
# 11/11 - 0s - loss: 0.8754 - accuracy: 0.6211 - 40ms/epoch - 4ms/step
# Epoch 524/1000
# 11/11 - 0s - loss: 0.8672 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 525/1000
# 11/11 - 0s - loss: 0.9103 - accuracy: 0.6304 - 37ms/epoch - 3ms/step
# Epoch 526/1000
# 11/11 - 0s - loss: 1.0069 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 527/1000
# 11/11 - 0s - loss: 0.9422 - accuracy: 0.6056 - 38ms/epoch - 3ms/step
# Epoch 528/1000
# 11/11 - 0s - loss: 0.9137 - accuracy: 0.6056 - 38ms/epoch - 3ms/step
# Epoch 529/1000
# 11/11 - 0s - loss: 0.8567 - accuracy: 0.6398 - 39ms/epoch - 4ms/step
# Epoch 530/1000
# 11/11 - 0s - loss: 0.8908 - accuracy: 0.6304 - 36ms/epoch - 3ms/step
# Epoch 531/1000
# 11/11 - 0s - loss: 0.8591 - accuracy: 0.6584 - 41ms/epoch - 4ms/step
# Epoch 532/1000
# 11/11 - 0s - loss: 0.8793 - accuracy: 0.6273 - 38ms/epoch - 3ms/step
# Epoch 533/1000
# 11/11 - 0s - loss: 0.8883 - accuracy: 0.6460 - 38ms/epoch - 3ms/step
# Epoch 534/1000
# 11/11 - 0s - loss: 0.9391 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 535/1000
# 11/11 - 0s - loss: 0.8567 - accuracy: 0.6708 - 40ms/epoch - 4ms/step
# Epoch 536/1000
# 11/11 - 0s - loss: 0.8817 - accuracy: 0.6429 - 39ms/epoch - 4ms/step
# Epoch 537/1000
# 11/11 - 0s - loss: 0.8633 - accuracy: 0.6335 - 40ms/epoch - 4ms/step
# Epoch 538/1000
# 11/11 - 0s - loss: 0.8878 - accuracy: 0.6398 - 48ms/epoch - 4ms/step
# Epoch 539/1000
# 11/11 - 0s - loss: 0.8628 - accuracy: 0.6242 - 47ms/epoch - 4ms/step
# Epoch 540/1000
# 11/11 - 0s - loss: 0.8531 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 541/1000
# 11/11 - 0s - loss: 0.8603 - accuracy: 0.6584 - 36ms/epoch - 3ms/step
# Epoch 542/1000
# 11/11 - 0s - loss: 0.8816 - accuracy: 0.6429 - 38ms/epoch - 3ms/step
# Epoch 543/1000
# 11/11 - 0s - loss: 0.8367 - accuracy: 0.6429 - 39ms/epoch - 4ms/step
# Epoch 544/1000
# 11/11 - 0s - loss: 0.8400 - accuracy: 0.6429 - 37ms/epoch - 3ms/step
# Epoch 545/1000
# 11/11 - 0s - loss: 0.8593 - accuracy: 0.6304 - 38ms/epoch - 3ms/step
# Epoch 546/1000
# 11/11 - 0s - loss: 0.9128 - accuracy: 0.6335 - 42ms/epoch - 4ms/step
# Epoch 547/1000
# 11/11 - 0s - loss: 0.8582 - accuracy: 0.6522 - 39ms/epoch - 4ms/step
# Epoch 548/1000
# 11/11 - 0s - loss: 0.8711 - accuracy: 0.6366 - 38ms/epoch - 3ms/step
# Epoch 549/1000
# 11/11 - 0s - loss: 0.9127 - accuracy: 0.6118 - 37ms/epoch - 3ms/step
# Epoch 550/1000
# 11/11 - 0s - loss: 0.8828 - accuracy: 0.6366 - 36ms/epoch - 3ms/step
# Epoch 551/1000
# 11/11 - 0s - loss: 0.8404 - accuracy: 0.6522 - 41ms/epoch - 4ms/step
# Epoch 552/1000
# 11/11 - 0s - loss: 0.8656 - accuracy: 0.6553 - 38ms/epoch - 3ms/step
# Epoch 553/1000
# 11/11 - 0s - loss: 0.8767 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 554/1000
# 11/11 - 0s - loss: 0.8754 - accuracy: 0.6273 - 42ms/epoch - 4ms/step
# Epoch 555/1000
# 11/11 - 0s - loss: 0.8378 - accuracy: 0.6739 - 43ms/epoch - 4ms/step
# Epoch 556/1000
# 11/11 - 0s - loss: 0.8709 - accuracy: 0.6273 - 38ms/epoch - 3ms/step
# Epoch 557/1000
# 11/11 - 0s - loss: 0.8877 - accuracy: 0.6335 - 39ms/epoch - 4ms/step
# Epoch 558/1000
# 11/11 - 0s - loss: 0.8854 - accuracy: 0.6273 - 38ms/epoch - 3ms/step
# Epoch 559/1000
# 11/11 - 0s - loss: 0.8862 - accuracy: 0.6460 - 41ms/epoch - 4ms/step
# Epoch 560/1000
# 11/11 - 0s - loss: 0.8770 - accuracy: 0.6398 - 42ms/epoch - 4ms/step
# Epoch 561/1000
# 11/11 - 0s - loss: 0.8821 - accuracy: 0.6056 - 40ms/epoch - 4ms/step
# Epoch 562/1000
# 11/11 - 0s - loss: 0.8982 - accuracy: 0.6149 - 45ms/epoch - 4ms/step
# Epoch 563/1000
# 11/11 - 0s - loss: 0.8768 - accuracy: 0.6304 - 52ms/epoch - 5ms/step
# Epoch 564/1000
# 11/11 - 0s - loss: 0.8496 - accuracy: 0.6460 - 38ms/epoch - 3ms/step
# Epoch 565/1000
# 11/11 - 0s - loss: 0.8422 - accuracy: 0.6491 - 39ms/epoch - 4ms/step
# Epoch 566/1000
# 11/11 - 0s - loss: 0.8252 - accuracy: 0.6646 - 42ms/epoch - 4ms/step
# Epoch 567/1000
# 11/11 - 0s - loss: 0.8255 - accuracy: 0.6429 - 42ms/epoch - 4ms/step
# Epoch 568/1000
# 11/11 - 0s - loss: 0.8841 - accuracy: 0.6149 - 41ms/epoch - 4ms/step
# Epoch 569/1000
# 11/11 - 0s - loss: 0.8601 - accuracy: 0.6677 - 38ms/epoch - 3ms/step
# Epoch 570/1000
# 11/11 - 0s - loss: 0.8605 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 571/1000
# 11/11 - 0s - loss: 0.8629 - accuracy: 0.6429 - 41ms/epoch - 4ms/step
# Epoch 572/1000
# ...
# Epoch 811/1000
# 11/11 - 0s - loss: 0.8738 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 812/1000
# 11/11 - 0s - loss: 0.8084 - accuracy: 0.6491 - 41ms/epoch - 4ms/step
# Epoch 813/1000
# 11/11 - 0s - loss: 0.8296 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 814/1000
# 11/11 - 0s - loss: 0.8543 - accuracy: 0.6273 - 40ms/epoch - 4ms/step
# Epoch 815/1000
# 11/11 - 0s - loss: 0.8321 - accuracy: 0.6460 - 45ms/epoch - 4ms/step
# Epoch 816/1000
# 11/11 - 0s - loss: 0.8387 - accuracy: 0.6366 - 40ms/epoch - 4ms/step
# Epoch 817/1000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6366 - 42ms/epoch - 4ms/step
# Epoch 818/1000
# 11/11 - 0s - loss: 0.8518 - accuracy: 0.6398 - 40ms/epoch - 4ms/step
# Epoch 819/1000
# 11/11 - 0s - loss: 0.8663 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 820/1000
# 11/11 - 0s - loss: 0.8439 - accuracy: 0.6180 - 51ms/epoch - 5ms/step
# Epoch 821/1000
# 11/11 - 0s - loss: 0.8864 - accuracy: 0.6056 - 36ms/epoch - 3ms/step
# Epoch 822/1000
# 11/11 - 0s - loss: 0.8527 - accuracy: 0.6304 - 41ms/epoch - 4ms/step
# Epoch 823/1000
# 11/11 - 0s - loss: 0.8750 - accuracy: 0.6522 - 42ms/epoch - 4ms/step
# Epoch 824/1000
# 11/11 - 0s - loss: 0.8935 - accuracy: 0.5963 - 36ms/epoch - 3ms/step
# Epoch 825/1000
# 11/11 - 0s - loss: 0.8123 - accuracy: 0.6429 - 39ms/epoch - 4ms/step
# Epoch 826/1000
# 11/11 - 0s - loss: 0.8257 - accuracy: 0.6211 - 39ms/epoch - 4ms/step
# Epoch 827/1000
# 11/11 - 0s - loss: 0.8081 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 828/1000
# 11/11 - 0s - loss: 0.8185 - accuracy: 0.6615 - 37ms/epoch - 3ms/step
# Epoch 829/1000
# 11/11 - 0s - loss: 0.8625 - accuracy: 0.6056 - 38ms/epoch - 3ms/step
# Epoch 830/1000
# 11/11 - 0s - loss: 0.8583 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 831/1000
# 11/11 - 0s - loss: 0.8563 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 832/1000
# 11/11 - 0s - loss: 0.8359 - accuracy: 0.6491 - 40ms/epoch - 4ms/step
# Epoch 833/1000
# 11/11 - 0s - loss: 0.8616 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 834/1000
# 11/11 - 0s - loss: 0.8379 - accuracy: 0.6273 - 40ms/epoch - 4ms/step
# Epoch 835/1000
# 11/11 - 0s - loss: 0.8073 - accuracy: 0.6491 - 35ms/epoch - 3ms/step
# Epoch 836/1000
# 11/11 - 0s - loss: 0.8178 - accuracy: 0.6553 - 37ms/epoch - 3ms/step
# Epoch 837/1000
# 11/11 - 0s - loss: 0.8116 - accuracy: 0.6491 - 44ms/epoch - 4ms/step
# Epoch 838/1000
# 11/11 - 0s - loss: 0.9337 - accuracy: 0.6211 - 36ms/epoch - 3ms/step
# Epoch 839/1000
# 11/11 - 0s - loss: 0.9022 - accuracy: 0.6118 - 40ms/epoch - 4ms/step
# Epoch 840/1000
# 11/11 - 0s - loss: 0.8428 - accuracy: 0.6273 - 36ms/epoch - 3ms/step
# Epoch 841/1000
# 11/11 - 0s - loss: 0.8207 - accuracy: 0.6491 - 40ms/epoch - 4ms/step
# Epoch 842/1000
# 11/11 - 0s - loss: 0.8790 - accuracy: 0.6180 - 38ms/epoch - 3ms/step
# Epoch 843/1000
# 11/11 - 0s - loss: 0.8351 - accuracy: 0.6335 - 40ms/epoch - 4ms/step
# Epoch 844/1000
# 11/11 - 0s - loss: 0.8360 - accuracy: 0.6584 - 50ms/epoch - 5ms/step
# Epoch 845/1000
# 11/11 - 0s - loss: 0.8686 - accuracy: 0.6025 - 45ms/epoch - 4ms/step
# Epoch 846/1000
# 11/11 - 0s - loss: 0.8391 - accuracy: 0.6491 - 35ms/epoch - 3ms/step
# Epoch 847/1000
# 11/11 - 0s - loss: 0.8818 - accuracy: 0.6087 - 43ms/epoch - 4ms/step
# Epoch 848/1000
# 11/11 - 0s - loss: 0.8423 - accuracy: 0.6398 - 36ms/epoch - 3ms/step
# Epoch 849/1000
# 11/11 - 0s - loss: 0.8439 - accuracy: 0.6242 - 36ms/epoch - 3ms/step
# Epoch 850/1000
# 11/11 - 0s - loss: 0.8397 - accuracy: 0.6304 - 43ms/epoch - 4ms/step
# Epoch 851/1000
# 11/11 - 0s - loss: 0.8177 - accuracy: 0.6522 - 36ms/epoch - 3ms/step
# Epoch 852/1000
# 11/11 - 0s - loss: 0.8151 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 853/1000
# 11/11 - 0s - loss: 0.8368 - accuracy: 0.6398 - 36ms/epoch - 3ms/step
# Epoch 854/1000
# 11/11 - 0s - loss: 0.8593 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 855/1000
# 11/11 - 0s - loss: 0.8504 - accuracy: 0.6304 - 59ms/epoch - 5ms/step
# Epoch 856/1000
# 11/11 - 0s - loss: 0.8516 - accuracy: 0.6366 - 43ms/epoch - 4ms/step
# Epoch 857/1000
# 11/11 - 0s - loss: 0.9178 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 858/1000
# 11/11 - 0s - loss: 0.8488 - accuracy: 0.6366 - 43ms/epoch - 4ms/step
# Epoch 859/1000
# 11/11 - 0s - loss: 0.8368 - accuracy: 0.6491 - 37ms/epoch - 3ms/step
# Epoch 860/1000
# 11/11 - 0s - loss: 0.8175 - accuracy: 0.6584 - 37ms/epoch - 3ms/step
# Epoch 861/1000
# 11/11 - 0s - loss: 0.8290 - accuracy: 0.6460 - 36ms/epoch - 3ms/step
# Epoch 862/1000
# 11/11 - 0s - loss: 0.8123 - accuracy: 0.6491 - 36ms/epoch - 3ms/step
# Epoch 863/1000
# 11/11 - 0s - loss: 0.8233 - accuracy: 0.6491 - 36ms/epoch - 3ms/step
# Epoch 864/1000
# 11/11 - 0s - loss: 0.8366 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 865/1000
# 11/11 - 0s - loss: 0.8402 - accuracy: 0.6460 - 36ms/epoch - 3ms/step
# Epoch 866/1000
# 11/11 - 0s - loss: 0.8181 - accuracy: 0.6739 - 42ms/epoch - 4ms/step
# Epoch 867/1000
# 11/11 - 0s - loss: 0.8469 - accuracy: 0.6429 - 40ms/epoch - 4ms/step
# Epoch 868/1000
# 11/11 - 0s - loss: 0.8087 - accuracy: 0.6553 - 56ms/epoch - 5ms/step
# Epoch 869/1000
# 11/11 - 0s - loss: 0.8339 - accuracy: 0.6429 - 40ms/epoch - 4ms/step
# Epoch 870/1000
# 11/11 - 0s - loss: 0.8656 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 871/1000
# 11/11 - 0s - loss: 0.8733 - accuracy: 0.6366 - 46ms/epoch - 4ms/step
# Epoch 872/1000
# 11/11 - 0s - loss: 0.8907 - accuracy: 0.6304 - 40ms/epoch - 4ms/step
# Epoch 873/1000
# 11/11 - 0s - loss: 0.8808 - accuracy: 0.6149 - 37ms/epoch - 3ms/step
# Epoch 874/1000
# 11/11 - 0s - loss: 0.8701 - accuracy: 0.6118 - 39ms/epoch - 4ms/step
# Epoch 875/1000
# 11/11 - 0s - loss: 0.8622 - accuracy: 0.6118 - 41ms/epoch - 4ms/step
# Epoch 876/1000
# 11/11 - 0s - loss: 0.8918 - accuracy: 0.6025 - 40ms/epoch - 4ms/step
# Epoch 877/1000
# 11/11 - 0s - loss: 0.8697 - accuracy: 0.6211 - 40ms/epoch - 4ms/step
# Epoch 878/1000
# 11/11 - 0s - loss: 0.8489 - accuracy: 0.6460 - 42ms/epoch - 4ms/step
# Epoch 879/1000
# 11/11 - 0s - loss: 0.8474 - accuracy: 0.6242 - 43ms/epoch - 4ms/step
# Epoch 880/1000
# 11/11 - 0s - loss: 0.8174 - accuracy: 0.6522 - 41ms/epoch - 4ms/step
# Epoch 881/1000
# 11/11 - 0s - loss: 0.8799 - accuracy: 0.6149 - 39ms/epoch - 4ms/step
# Epoch 882/1000
# 11/11 - 0s - loss: 0.8598 - accuracy: 0.6149 - 40ms/epoch - 4ms/step
# Epoch 883/1000
# 11/11 - 0s - loss: 0.8923 - accuracy: 0.6211 - 38ms/epoch - 3ms/step
# Epoch 884/1000
# 11/11 - 0s - loss: 0.8680 - accuracy: 0.6025 - 40ms/epoch - 4ms/step
# Epoch 885/1000
# 11/11 - 0s - loss: 0.8639 - accuracy: 0.6398 - 40ms/epoch - 4ms/step
# Epoch 886/1000
# 11/11 - 0s - loss: 0.8279 - accuracy: 0.6304 - 36ms/epoch - 3ms/step
# Epoch 887/1000
# 11/11 - 0s - loss: 0.8390 - accuracy: 0.6491 - 35ms/epoch - 3ms/step
# Epoch 888/1000
# 11/11 - 0s - loss: 0.8527 - accuracy: 0.6211 - 37ms/epoch - 3ms/step
# Epoch 889/1000
# 11/11 - 0s - loss: 0.8526 - accuracy: 0.6398 - 34ms/epoch - 3ms/step
# Epoch 890/1000
# 11/11 - 0s - loss: 0.9006 - accuracy: 0.6304 - 40ms/epoch - 4ms/step
# Epoch 891/1000
# 11/11 - 0s - loss: 0.8558 - accuracy: 0.6460 - 53ms/epoch - 5ms/step
# Epoch 892/1000
# 11/11 - 0s - loss: 0.8148 - accuracy: 0.6584 - 36ms/epoch - 3ms/step
# Epoch 893/1000
# 11/11 - 0s - loss: 0.8191 - accuracy: 0.6677 - 39ms/epoch - 4ms/step
# Epoch 894/1000
# 11/11 - 0s - loss: 0.8893 - accuracy: 0.6118 - 36ms/epoch - 3ms/step
# Epoch 895/1000
# 11/11 - 0s - loss: 0.8565 - accuracy: 0.6398 - 38ms/epoch - 3ms/step
# Epoch 896/1000
# 11/11 - 0s - loss: 0.8789 - accuracy: 0.6615 - 36ms/epoch - 3ms/step
# Epoch 897/1000
# 11/11 - 0s - loss: 0.8051 - accuracy: 0.6304 - 36ms/epoch - 3ms/step
# Epoch 898/1000
# 11/11 - 0s - loss: 0.8308 - accuracy: 0.6460 - 37ms/epoch - 3ms/step
# Epoch 899/1000
# 11/11 - 0s - loss: 0.8655 - accuracy: 0.6522 - 37ms/epoch - 3ms/step
# Epoch 900/1000
# 11/11 - 0s - loss: 0.9186 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 901/1000
# 11/11 - 0s - loss: 0.8839 - accuracy: 0.6056 - 37ms/epoch - 3ms/step
# Epoch 902/1000
# 11/11 - 0s - loss: 0.8449 - accuracy: 0.6460 - 36ms/epoch - 3ms/step
# Epoch 903/1000
# 11/11 - 0s - loss: 0.8331 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 904/1000
# 11/11 - 0s - loss: 0.8835 - accuracy: 0.6242 - 38ms/epoch - 3ms/step
# Epoch 905/1000
# 11/11 - 0s - loss: 0.8329 - accuracy: 0.6429 - 35ms/epoch - 3ms/step
# Epoch 906/1000
# 11/11 - 0s - loss: 0.8602 - accuracy: 0.6273 - 36ms/epoch - 3ms/step
# Epoch 907/1000
# 11/11 - 0s - loss: 0.8046 - accuracy: 0.6553 - 37ms/epoch - 3ms/step
# Epoch 908/1000
# 11/11 - 0s - loss: 0.8234 - accuracy: 0.6553 - 40ms/epoch - 4ms/step
# Epoch 909/1000
# 11/11 - 0s - loss: 0.8094 - accuracy: 0.6739 - 39ms/epoch - 4ms/step
# Epoch 910/1000
# 11/11 - 0s - loss: 0.8040 - accuracy: 0.6646 - 40ms/epoch - 4ms/step
# Epoch 911/1000
# 11/11 - 0s - loss: 0.8084 - accuracy: 0.6553 - 36ms/epoch - 3ms/step
# Epoch 912/1000
# 11/11 - 0s - loss: 0.8390 - accuracy: 0.6398 - 37ms/epoch - 3ms/step
# Epoch 913/1000
# 11/11 - 0s - loss: 0.8474 - accuracy: 0.6211 - 37ms/epoch - 3ms/step
# Epoch 914/1000
# 11/11 - 0s - loss: 0.8291 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 915/1000
# 11/11 - 0s - loss: 0.8307 - accuracy: 0.6242 - 43ms/epoch - 4ms/step
# Epoch 916/1000
# 11/11 - 0s - loss: 0.8062 - accuracy: 0.6335 - 48ms/epoch - 4ms/step
# Epoch 917/1000
# 11/11 - 0s - loss: 0.8419 - accuracy: 0.6211 - 43ms/epoch - 4ms/step
# Epoch 918/1000
# 11/11 - 0s - loss: 0.7962 - accuracy: 0.6366 - 36ms/epoch - 3ms/step
# Epoch 919/1000
# 11/11 - 0s - loss: 0.8139 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 920/1000
# 11/11 - 0s - loss: 0.9278 - accuracy: 0.5839 - 36ms/epoch - 3ms/step
# Epoch 921/1000
# 11/11 - 0s - loss: 0.8762 - accuracy: 0.6273 - 35ms/epoch - 3ms/step
# Epoch 922/1000
# 11/11 - 0s - loss: 0.8795 - accuracy: 0.6429 - 36ms/epoch - 3ms/step
# Epoch 923/1000
# 11/11 - 0s - loss: 0.8139 - accuracy: 0.6429 - 35ms/epoch - 3ms/step
# Epoch 924/1000
# 11/11 - 0s - loss: 0.8253 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 925/1000
# 11/11 - 0s - loss: 0.8012 - accuracy: 0.6677 - 39ms/epoch - 4ms/step
# Epoch 926/1000
# 11/11 - 0s - loss: 0.8059 - accuracy: 0.6615 - 37ms/epoch - 3ms/step
# Epoch 927/1000
# 11/11 - 0s - loss: 0.8286 - accuracy: 0.6460 - 37ms/epoch - 3ms/step
# Epoch 928/1000
# 11/11 - 0s - loss: 0.8474 - accuracy: 0.6242 - 36ms/epoch - 3ms/step
# Epoch 929/1000
# 11/11 - 0s - loss: 0.8244 - accuracy: 0.6677 - 38ms/epoch - 3ms/step
# Epoch 930/1000
# 11/11 - 0s - loss: 0.8688 - accuracy: 0.6242 - 35ms/epoch - 3ms/step
# Epoch 931/1000
# 11/11 - 0s - loss: 0.8528 - accuracy: 0.6335 - 36ms/epoch - 3ms/step
# Epoch 932/1000
# 11/11 - 0s - loss: 0.8087 - accuracy: 0.6398 - 45ms/epoch - 4ms/step
# Epoch 933/1000
# 11/11 - 0s - loss: 0.8257 - accuracy: 0.6273 - 36ms/epoch - 3ms/step
# Epoch 934/1000
# 11/11 - 0s - loss: 0.8670 - accuracy: 0.6366 - 35ms/epoch - 3ms/step
# Epoch 935/1000
# 11/11 - 0s - loss: 0.8090 - accuracy: 0.6460 - 35ms/epoch - 3ms/step
# Epoch 936/1000
# 11/11 - 0s - loss: 0.8191 - accuracy: 0.6398 - 36ms/epoch - 3ms/step
# Epoch 937/1000
# 11/11 - 0s - loss: 0.8158 - accuracy: 0.6366 - 40ms/epoch - 4ms/step
# Epoch 938/1000
# 11/11 - 0s - loss: 0.8242 - accuracy: 0.6491 - 39ms/epoch - 4ms/step
# Epoch 939/1000
# 11/11 - 0s - loss: 0.8357 - accuracy: 0.6335 - 38ms/epoch - 3ms/step
# Epoch 940/1000
# 11/11 - 0s - loss: 0.8459 - accuracy: 0.6491 - 40ms/epoch - 4ms/step
# Epoch 941/1000
# 11/11 - 0s - loss: 0.8684 - accuracy: 0.6118 - 37ms/epoch - 3ms/step
# Epoch 942/1000
# 11/11 - 0s - loss: 0.8996 - accuracy: 0.6429 - 36ms/epoch - 3ms/step
# Epoch 943/1000
# 11/11 - 0s - loss: 0.8429 - accuracy: 0.6646 - 36ms/epoch - 3ms/step
# Epoch 944/1000
# 11/11 - 0s - loss: 0.8293 - accuracy: 0.6522 - 37ms/epoch - 3ms/step
# Epoch 945/1000
# 11/11 - 0s - loss: 0.8393 - accuracy: 0.6335 - 37ms/epoch - 3ms/step
# Epoch 946/1000
# 11/11 - 0s - loss: 0.9052 - accuracy: 0.6056 - 41ms/epoch - 4ms/step
# Epoch 947/1000
# 11/11 - 0s - loss: 0.8693 - accuracy: 0.6211 - 36ms/epoch - 3ms/step
# Epoch 948/1000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6242 - 36ms/epoch - 3ms/step
# Epoch 949/1000
# 11/11 - 0s - loss: 0.8217 - accuracy: 0.6429 - 37ms/epoch - 3ms/step
# Epoch 950/1000
# 11/11 - 0s - loss: 0.8478 - accuracy: 0.6273 - 39ms/epoch - 4ms/step
# Epoch 951/1000
# 11/11 - 0s - loss: 0.8062 - accuracy: 0.6429 - 39ms/epoch - 4ms/step
# Epoch 952/1000
# 11/11 - 0s - loss: 0.8247 - accuracy: 0.6335 - 37ms/epoch - 3ms/step
# Epoch 953/1000
# 11/11 - 0s - loss: 0.8160 - accuracy: 0.6398 - 35ms/epoch - 3ms/step
# Epoch 954/1000
# 11/11 - 0s - loss: 0.8502 - accuracy: 0.6180 - 38ms/epoch - 3ms/step
# Epoch 955/1000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6273 - 35ms/epoch - 3ms/step
# Epoch 956/1000
# 11/11 - 0s - loss: 0.8601 - accuracy: 0.6304 - 33ms/epoch - 3ms/step
# Epoch 957/1000
# 11/11 - 0s - loss: 0.8285 - accuracy: 0.6304 - 35ms/epoch - 3ms/step
# Epoch 958/1000
# 11/11 - 0s - loss: 0.8281 - accuracy: 0.6366 - 39ms/epoch - 4ms/step
# Epoch 959/1000
# 11/11 - 0s - loss: 0.8346 - accuracy: 0.6335 - 36ms/epoch - 3ms/step
# Epoch 960/1000
# 11/11 - 0s - loss: 0.8003 - accuracy: 0.6429 - 37ms/epoch - 3ms/step
# Epoch 961/1000
# 11/11 - 0s - loss: 0.8162 - accuracy: 0.6615 - 36ms/epoch - 3ms/step
# Epoch 962/1000
# 11/11 - 0s - loss: 0.8454 - accuracy: 0.6366 - 38ms/epoch - 3ms/step
# Epoch 963/1000
# 11/11 - 0s - loss: 0.8398 - accuracy: 0.6429 - 42ms/epoch - 4ms/step
# Epoch 964/1000
# 11/11 - 0s - loss: 0.8274 - accuracy: 0.6491 - 36ms/epoch - 3ms/step
# Epoch 965/1000
# 11/11 - 0s - loss: 0.8525 - accuracy: 0.6211 - 40ms/epoch - 4ms/step
# Epoch 966/1000
# 11/11 - 0s - loss: 0.8217 - accuracy: 0.6522 - 40ms/epoch - 4ms/step
# Epoch 967/1000
# 11/11 - 0s - loss: 0.8749 - accuracy: 0.6087 - 35ms/epoch - 3ms/step
# Epoch 968/1000
# 11/11 - 0s - loss: 0.8298 - accuracy: 0.6429 - 36ms/epoch - 3ms/step
# Epoch 969/1000
# 11/11 - 0s - loss: 0.8535 - accuracy: 0.6180 - 34ms/epoch - 3ms/step
# Epoch 970/1000
# 11/11 - 0s - loss: 0.8057 - accuracy: 0.6584 - 36ms/epoch - 3ms/step
# Epoch 971/1000
# 11/11 - 0s - loss: 0.8587 - accuracy: 0.5963 - 34ms/epoch - 3ms/step
# Epoch 972/1000
# 11/11 - 0s - loss: 0.8539 - accuracy: 0.6273 - 37ms/epoch - 3ms/step
# Epoch 973/1000
# 11/11 - 0s - loss: 0.8386 - accuracy: 0.6366 - 35ms/epoch - 3ms/step
# Epoch 974/1000
# 11/11 - 0s - loss: 0.8178 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 975/1000
# 11/11 - 0s - loss: 0.8530 - accuracy: 0.6180 - 41ms/epoch - 4ms/step
# Epoch 976/1000
# 11/11 - 0s - loss: 0.8270 - accuracy: 0.6242 - 38ms/epoch - 3ms/step
# Epoch 977/1000
# 11/11 - 0s - loss: 0.7936 - accuracy: 0.6522 - 34ms/epoch - 3ms/step
# Epoch 978/1000
# 11/11 - 0s - loss: 0.8590 - accuracy: 0.6335 - 35ms/epoch - 3ms/step
# Epoch 979/1000
# 11/11 - 0s - loss: 0.8717 - accuracy: 0.6211 - 33ms/epoch - 3ms/step
# Epoch 980/1000
# 11/11 - 0s - loss: 0.8402 - accuracy: 0.6304 - 36ms/epoch - 3ms/step
# Epoch 981/1000
# 11/11 - 0s - loss: 0.8108 - accuracy: 0.6708 - 33ms/epoch - 3ms/step
# Epoch 982/1000
# 11/11 - 0s - loss: 0.8437 - accuracy: 0.6429 - 34ms/epoch - 3ms/step
# Epoch 983/1000
# 11/11 - 0s - loss: 0.8193 - accuracy: 0.6335 - 34ms/epoch - 3ms/step
# Epoch 984/1000
# 11/11 - 0s - loss: 0.8613 - accuracy: 0.6273 - 35ms/epoch - 3ms/step
# Epoch 985/1000
# 11/11 - 0s - loss: 0.8004 - accuracy: 0.6832 - 41ms/epoch - 4ms/step
# Epoch 986/1000
# 11/11 - 0s - loss: 0.8057 - accuracy: 0.6460 - 35ms/epoch - 3ms/step
# Epoch 987/1000
# 11/11 - 0s - loss: 0.8235 - accuracy: 0.6491 - 38ms/epoch - 3ms/step
# Epoch 988/1000
# 11/11 - 0s - loss: 0.8338 - accuracy: 0.6522 - 38ms/epoch - 3ms/step
# Epoch 989/1000
# 11/11 - 0s - loss: 0.7812 - accuracy: 0.6522 - 35ms/epoch - 3ms/step
# Epoch 990/1000
# 11/11 - 0s - loss: 0.7945 - accuracy: 0.6429 - 40ms/epoch - 4ms/step
# Epoch 991/1000
# 11/11 - 0s - loss: 0.8326 - accuracy: 0.6460 - 44ms/epoch - 4ms/step
# Epoch 992/1000
# 11/11 - 0s - loss: 0.7986 - accuracy: 0.6429 - 38ms/epoch - 3ms/step
# Epoch 993/1000
# 11/11 - 0s - loss: 0.8149 - accuracy: 0.6398 - 36ms/epoch - 3ms/step
# Epoch 994/1000
# 11/11 - 0s - loss: 0.8004 - accuracy: 0.6708 - 36ms/epoch - 3ms/step
# Epoch 995/1000
# 11/11 - 0s - loss: 0.8388 - accuracy: 0.6180 - 35ms/epoch - 3ms/step
# Epoch 996/1000
# 11/11 - 0s - loss: 0.8359 - accuracy: 0.6304 - 37ms/epoch - 3ms/step
# Epoch 997/1000
# 11/11 - 0s - loss: 0.7884 - accuracy: 0.6739 - 36ms/epoch - 3ms/step
# Epoch 998/1000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6025 - 37ms/epoch - 3ms/step
# Epoch 999/1000
# 11/11 - 0s - loss: 0.8201 - accuracy: 0.6677 - 46ms/epoch - 4ms/step
# Epoch 1000/1000
# 11/11 - 0s - loss: 0.8423 - accuracy: 0.6242 - 38ms/epoch - 3ms/step

# %%
def recommend_makanan(category, taste):
    # Create the feature vector for the selected category and taste
    selected_features = category + ' ' + taste
    selected_vector = tfidf.transform([selected_features]).toarray()

    # Predict similarity scores
    predictions = model.predict(selected_vector)

    # Get the top 3 recommendations
    recommended_indices = predictions[0].argsort()[-10:][::-1]
    recommended_makanan = makanan_data.iloc[recommended_indices]['makanan/minuman'].values
    return recommended_makanan

# %% [markdown]
# inputan Dropdown button & free text

# %%
#buat sesuai kebutuhan kategori (Makanan Berat, Makanan Ringan, Jajanan, Minuman)
category_input = 'Makanan Berat'

# %%
#inputan free text
taste_input = 'Gurih, pedas'

# %%
recommended_makanan = recommend_makanan(category_input, taste_input)
print(f"Rekomendasi makanan untuk kategori '{category_input}' dengan rasa '{taste_input}':")
for makanan in recommended_makanan:
    print(f"- {makanan}")
# Out:
# 1/1 [==============================] - 0s 340ms/step
# Rekomendasi makanan untuk kategori 'Makanan Berat' dengan rasa 'Gurih, pedas':
# - Nasi Pecel
# - Gado-gado
# - Lotek
# - Karedok
# - Oseng Kangkung
# - Empal Bacem
# - Empal Goreng
# - Mie Aceh
# - Sate kronyos
# - Sate Ayam

# %% [markdown]
# #Rekomendasi restoran berdasarkan makanan yang dipilih

# %%
def recommend_restaurants_for_selected_food(selected_food):
    recommended_restaurants = []

    for i, row in restoran_data.iterrows():
        if selected_food in row['variasi_makanan']:
            recommended_restaurants.append((row['nama_restoran'], row['rating_toko'], row['variasi_makanan']))

    return recommended_restaurants

# %% [markdown]
# Cosine Similarity

# %%
# Replace NaN values with empty string
restoran_data['variasi_makanan'].fillna('', inplace=True)

# TF-IDF matrix for restaurant data
tfidf_matrix_restaurant = tfidf.transform(restoran_data['variasi_makanan'])

# Compute cosine similarity between food and restaurant TF-IDF matrices
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix_restaurant)

def recommend_restaurants_for_food_containing_keyword(keyword, cosine_sim, makanan_data, restoran_data):
    # Find the indices of foods that contain the keyword
    food_indices = makanan_data[makanan_data['makanan/minuman'].str.contains(keyword, case=False, na=False)].index.tolist()

    # Prepare the list of recommended restaurants with cosine similarity scores
    recommended_restaurants_with_scores = []

    for food_index in food_indices:
        # Compute and sort cosine similarity scores for each food
        sim_scores = list(enumerate(cosine_sim[food_index]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

        # Get top 3 similar restaurants with their cosine similarity scores for each food
        top_similar_restaurants = sim_scores[:5]

        for idx, score in top_similar_restaurants:
            recommended_restaurants_with_scores.append((restoran_data.iloc[idx]['nama_restoran'],
                                                        score, makanan_data.iloc[food_index]['makanan/minuman']))

    # Sort the final list by cosine similarity scores
    recommended_restaurants_with_scores.sort(key=lambda x: x[1], reverse=True)

    # Get unique recommendations, avoiding duplicates
    unique_recommendations = []
    seen_restaurants = set()
    for rec in recommended_restaurants_with_scores:
        if rec[0] not in seen_restaurants:
            seen_restaurants.add(rec[0])
            unique_recommendations.append(rec)

    return unique_recommendations[:5]
# Out:
# <ipython-input-29-59c2aa14ce45>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restoran_data['variasi_makanan'].fillna('', inplace=True)

# %%
selected_food = 'babi'
recommended_restaurants_with_scores = recommend_restaurants_for_food_containing_keyword(selected_food, cosine_sim, makanan_data, restoran_data)

print(f"Rekomendasi restoran yang menyediakan makanan/minuman yang mengandung kata '{selected_food}' dengan skor kesamaan kosinus:")
for nama_restoran, score, variasi_makanan in recommended_restaurants_with_scores:
    print(f"- {nama_restoran} (skor kesamaan: {score:.2f}) menyediakan {variasi_makanan}")
# Out:
# Rekomendasi restoran yang menyediakan makanan/minuman yang mengandung kata 'babi' dengan skor kesamaan kosinus:
# - Warung Lesehan Pak Kirun (skor kesamaan: 0.52) menyediakan Sate Babi
# - Madam Tan Indonesian Food (skor kesamaan: 0.43) menyediakan Sate Babi
# - Ayam Pedas Artomoro (skor kesamaan: 0.42) menyediakan Sate Babi
# - Waroeng spesial sambal "SS" Jakal KM 12 (skor kesamaan: 0.41) menyediakan Sate Babi
# - Katombo Sulawesi Grilled Fish (skor kesamaan: 0.40) menyediakan Sate Babi
